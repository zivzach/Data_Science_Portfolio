# %%
#Import of packages
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline
pd.set_option('display.max_columns', 10) 
pd.set_option('display.max_rows', 50) 
df=pd.read_csv("worldhappiness2019.csv")

#read in region csv
regiondata=pd.read_csv("region.csv")
regiondata
# Out:
#                name   region          sub-region
# 0       Afghanistan     Asia       Southern Asia
# 1     Åland Islands   Europe     Northern Europe
# 2           Albania   Europe     Southern Europe
# 3           Algeria   Africa     Northern Africa
# 4    American Samoa  Oceania           Polynesia
# ..              ...      ...                 ...
# 250  Western Sahara   Africa     Northern Africa
# 251           Yemen     Asia        Western Asia
# 252          Zambia   Africa  Sub-Saharan Africa
# 253        Zimbabwe   Africa  Sub-Saharan Africa
# 254     Ivory Coast   Africa  Sub-Saharan Africa
#
# [255 rows x 3 columns]

# %%
#sql join of region csv on country name in worldhappiness2019
mergedata=pd.merge(df, regiondata, how='left', left_on='Country or region', right_on='name')
# Checking for missing values 
mergedata.loc[pd.isnull(mergedata).iloc[:,9]].to_csv("missing.csv",index=False)

# %%
# clean up final csv data
df=mergedata.drop(['name'],axis=1)
df=df.drop(['Country or region'],axis=1)
df=df.drop(['sub-region'],axis=1)

df
# Out:
#     Happiness_level  GDP per capita  Social support  Healthy life expectancy  \
# 0         Very High           1.340           1.587                    0.986
# 1         Very High           1.383           1.573                    0.996
# 2         Very High           1.488           1.582                    1.028
# 3         Very High           1.380           1.624                    1.026
# 4         Very High           1.396           1.522                    0.999
# ..              ...             ...             ...                      ...
# 151        Very Low           0.359           0.711                    0.614
# 152        Very Low           0.476           0.885                    0.499
# 153        Very Low           0.350           0.517                    0.361
# 154        Very Low           0.026           0.000                    0.105
# 155        Very Low           0.306           0.575                    0.295
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                           0.596       0.153                      0.393
# 1                           0.592       0.252                      0.410
# 2                           0.603       0.271                      0.341
# 3                           0.591       0.354                      0.118
# 4                           0.557       0.322                      0.298
# ..                            ...         ...                        ...
# 151                         0.555       0.217                      0.411
# 152                         0.417       0.276                      0.147
# 153                         0.000       0.158                      0.025
# 154                         0.225       0.235                      0.035
# 155                         0.010       0.202                      0.091
#
#      region
# 0    Europe
# 1    Europe
# 2    Europe
# 3    Europe
# 4    Europe
# ..      ...
# 151  Africa
# 152  Africa
# 153    Asia
# 154  Africa
# 155  Africa
#
# [156 rows x 8 columns]

# %% [markdown]
# # Explore bivariate results (Use visualizations!)
# # Describe any relationships you see between particular features and the target variable

# %%
#For the purpose of visualization, I'm going to turn the target happiness level variable into a ordinal categorical variable
#Looking at the categorical values for hapiness_level
pd.crosstab(index=df['Happiness_level'],columns='count')
# Out:
# col_0            count
# Happiness_level
# Average             31
# High                32
# Low                 31
# Very High           31
# Very Low            31

# %%
#For the purpose of visualization, I'm going to turn the target happiness_level variable into a ordinal categorical variable
#This code turns the feature into a Likert Scale dummy variable
df
conditions = [
  (df['Happiness_level'] == 'Very High'),
  (df['Happiness_level'] == 'High'),
  (df['Happiness_level'] == 'Average'),
  (df['Happiness_level'] == 'Low'),
  (df['Happiness_level'] == 'Very Low')]
choices = [5,4,3,2,1]
df['Happiness_level'] = np.select(conditions, choices, default=np.nan)

# %%
#creates a correlational heatmap based on the bivariate relationship of features
sns.heatmap(df.corr(),robust=True,cmap="YlGnBu")

# %% [markdown]
# ***Answer*** *Looking at the correlational heatmap, it would seem that a few features are highly correlated with each other as well as the target feature of happiness_level. It would seem that GDP per capita, Social Support, and Health Life Expectancy all vary together as well as with happines level*

# %%
#Creates a series of bivariate distruptions diveded by region
sns.pairplot(df, hue='region')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ***Answer** Looking at the target variable of happiness, regional differences are quite large. With America and Europe being the most happy, Asia varying widely, and with Africa being considered mostly unhappy. Looking at the relationship with all of the features and happiness_level, georosity doesn't have a strong trend, with almost all countries following between the range of .3 to .1. So, genorosity does not seem to have an effect on happiness. THe strongest predictive variables seem to be GDP per capita, as it has a strong positive trend with happiness level. Also, it seems like falling between 1.0 to 1.5 gdp per capita is key to a high happiness level.

# %% [markdown]
# #Examine features that predict happiness categories using one or more models that allow for automatic feature selection
# #Explain any meaningful findings

# %%
#Reloading dataset because colab was being weird
#It's just a copy and paste of above code
df=pd.read_csv("worldhappiness2019.csv")
regiondata=pd.read_csv("region.csv")
mergedata=pd.merge(df, regiondata, how='left', left_on='Country or region', right_on='name')
df=mergedata.drop(['name'],axis=1)
df=df.drop(['Country or region'],axis=1)
df=df.drop(['sub-region'],axis=1)
df
# Out:
#     Happiness_level  GDP per capita  Social support  Healthy life expectancy  \
# 0         Very High           1.340           1.587                    0.986
# 1         Very High           1.383           1.573                    0.996
# 2         Very High           1.488           1.582                    1.028
# 3         Very High           1.380           1.624                    1.026
# 4         Very High           1.396           1.522                    0.999
# ..              ...             ...             ...                      ...
# 151        Very Low           0.359           0.711                    0.614
# 152        Very Low           0.476           0.885                    0.499
# 153        Very Low           0.350           0.517                    0.361
# 154        Very Low           0.026           0.000                    0.105
# 155        Very Low           0.306           0.575                    0.295
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                           0.596       0.153                      0.393
# 1                           0.592       0.252                      0.410
# 2                           0.603       0.271                      0.341
# 3                           0.591       0.354                      0.118
# 4                           0.557       0.322                      0.298
# ..                            ...         ...                        ...
# 151                         0.555       0.217                      0.411
# 152                         0.417       0.276                      0.147
# 153                         0.000       0.158                      0.025
# 154                         0.225       0.235                      0.035
# 155                         0.010       0.202                      0.091
#
#      region
# 0    Europe
# 1    Europe
# 2    Europe
# 3    Europe
# 4    Europe
# ..      ...
# 151  Africa
# 152  Africa
# 153    Asia
# 154  Africa
# 155  Africa
#
# [156 rows x 8 columns]

# %%
#crosstab of all regions
pd.crosstab(index=df['region'],columns='count')
# Out:
# col_0     count
# region
# Africa       45
# Americas     23
# Asia         46
# Europe       40
# Oceania       2

# %%
#creating dummies and concating them back to dataframe
df = pd.concat([df.drop('region', axis=1), pd.get_dummies(df['region'])], axis=1)
df.columns
# Out:
# Index(['Happiness_level', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Africa', 'Americas', 'Asia', 'Europe',
#        'Oceania'],
#       dtype='object')

# %%
# Set up training and test data
from sklearn.model_selection import train_test_split

y=df['Happiness_level']
X=df.drop(['Happiness_level'],axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
#Running a random forest classifier to hone in on important features
from sklearn.datasets import load_boston
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=200)
formodel = forest.fit(X_train, y_train)


print()

print(formodel.feature_importances_)
# Out:
# [0.19651164 0.16998319 0.17450869 0.1371431  0.09393166 0.13938879
#  0.02829131 0.02292516 0.02328909 0.01360641 0.00042097]

# %%
X.columns
# Out:
# Index(['GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Africa', 'Americas', 'Asia', 'Europe',
#        'Oceania'],
#       dtype='object')

# %% [markdown]
# **Answer** According to the automatic feature selection of my random forest classifier, GDP, Social Support, Health Life, Freedom, and perceptions of corruption had stronger predictive effects and are important in the determination of a country as happy. These results are similar to the ones from the correaltional visualizations

# %%
#Reading in data one last time because google colab was being weird with my dataframes
df=pd.read_csv("worldhappiness2019.csv")
regiondata=pd.read_csv("region.csv")
mergedata=pd.merge(df, regiondata, how='left', left_on='Country or region', right_on='name')
df=mergedata.drop(['name'],axis=1)
df=df.drop(['Country or region'],axis=1)
df=df.drop(['sub-region'],axis=1)

# %%
# Set up training and test data
from sklearn.model_selection import train_test_split

y=df['Happiness_level']
X=df.drop(['Happiness_level'],axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# # Run at least three prediction models to try to predict World Happiness well.

# %%
#Running Michael Parrots preprocessing pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# We create the preprocessing pipelines for both numeric and categorical data.

numeric_features=X.columns.tolist()
numeric_features.remove('region')

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_features = ['region']

#Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# final preprocessor object set up with ColumnTransformer

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])


#Fit your preprocessor object
prediction_input_preprocessor=preprocessor.fit(X_train) 

import pickle
pickle.dump(prediction_input_preprocessor, open( "preprocessor.pkl", "wb" ) )

# %%
#running Michael Parrots predicted label generator from the model
# using predict_classes() for multi-class data to return predicted class index.

print(model.predict_classes(prediction_input_preprocessor.transform(X_test)))

prediction_index=model.predict_classes(prediction_input_preprocessor.transform(X_test))

#Now lets run some code to get keras to return the label rather than the index...

# get labels from one hot encoded y_train data
labels=pd.get_dummies(y_train).columns

# Function to use to return label from column index location
def index_to_label(labels,index_n): 
    return labels[index_n]
    
# Example: return label at predicted index location 1
index_to_label(labels,1)

# Iterate through all predicted indices using map method

predicted_labels=list(map(lambda x: labels[x], prediction_index))
# Out:
# [3 3 3 3 0 3 4 3 3 0 3 3 3 3 3 3 4 0 4 3 0 3 3 3 3 0 3 3 3 0 3 0 3 0 3 0 0
#  4 3]

# %%
#Running Michael Parrots funtion on metric evaluation
#Metric formula
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
import pandas as pd
from math import sqrt

def model_eval_metrics(y_true, y_pred,classification="TRUE"):
     if classification=="TRUE":
        accuracy_eval = accuracy_score(y_true, y_pred)
        f1_score_eval = f1_score(y_true, y_pred,average="macro",zero_division=0)
        precision_eval = precision_score(y_true, y_pred,average="macro",zero_division=0)
        recall_eval = recall_score(y_true, y_pred,average="macro",zero_division=0)
        mse_eval = 0
        rmse_eval = 0
        mae_eval = 0
        r2_eval = 0
        metricdata = {'accuracy': [accuracy_eval], 'f1_score': [f1_score_eval], 'precision': [precision_eval], 'recall': [recall_eval], 'mse': [mse_eval], 'rmse': [rmse_eval], 'mae': [mae_eval], 'r2': [r2_eval]}
        finalmetricdata = pd.DataFrame.from_dict(metricdata)
     else:
        accuracy_eval = 0
        f1_score_eval = 0
        precision_eval = 0
        recall_eval = 0
        mse_eval = mean_squared_error(y_true, y_pred)
        rmse_eval = sqrt(mean_squared_error(y_true, y_pred))
        mae_eval = mean_absolute_error(y_true, y_pred)
        r2_eval = r2_score(y_true, y_pred)
        metricdata = {'accuracy': [accuracy_eval], 'f1_score': [f1_score_eval], 'precision': [precision_eval], 'recall': [recall_eval], 'mse': [mse_eval], 'rmse': [rmse_eval], 'mae': [mae_eval], 'r2': [r2_eval]}
        finalmetricdata = pd.DataFrame.from_dict(metricdata)
     return finalmetricdata

# %%
#Running a random forest classifier with 1000 trees
from numpy import loadtxt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score


#running a random forst classifier
model=RandomForestClassifier(n_estimators=1000, random_state = 0)
model.fit(prediction_input_preprocessor.transform(X_train), y_train)
y_pred=model.predict(prediction_input_preprocessor.transform(X_test))

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

print("Random Forest Classifier's accuracy:", np.mean(cross_val_score(model, prediction_input_preprocessor.transform(X_train), y_train, cv=10)))
print("Random Forest Classifier's accuracy on test data: {:.5f}".format(model.score(prediction_input_preprocessor.transform(X_test), y_test)))
# Out:
# Random Forest Classifier's accuracy: 0.6068181818181818
# Random Forest Classifier's accuracy on test data: 0.38462

# %%
#Using grid search cv to tune paramters
from sklearn.model_selection import GridSearchCV
rf_param_grid = {'max_depth': range(3,4),'n_estimators': range(99,100),'min_samples_leaf': range(7,8)}
rf_grid = GridSearchCV(RandomForestClassifier(),param_grid = rf_param_grid, cv=10)
rf_grid.fit(prediction_input_preprocessor.transform(X_train),y_train)
print("Test set score: {:.2f}".format(rf_grid.score(prediction_input_preprocessor.transform(X_test),y_test)))
print("Best Parameter: {}".format(rf_grid.best_params_))
# Out:
# Test set score: 0.46
# Best Parameter: {'max_depth': 3, 'min_samples_leaf': 7, 'n_estimators': 99}

# %% [markdown]
# **Note: I did run a few grid search cv's to tune paratmers before settiling on these parameters**

# %%
#Running hyper tuned model and evaluating it
model=RandomForestClassifier(n_estimators=8, random_state = 0,max_depth = 3,min_samples_leaf = 1)
model.fit(prediction_input_preprocessor.transform(X_train), y_train)
y_pred=model.predict(prediction_input_preprocessor.transform(X_test))

# %%
#evaluating model
modelevalobject=model_eval_metrics(y_test,y_pred,classification="TRUE")
modelevalobject
# Out:
#    accuracy  f1_score  precision  recall  mse  rmse  mae  r2
# 0  0.410256  0.417914   0.486616   0.425    0     0    0   0

# %% [markdown]
# **Answer** I used n_estimators, min_sample_leaf, and max depth to tune the random forest classifier. max_depth gives the algorithim the ceiling for how many decision deep it can get, min_sample_leaf tells the algorithim how many samples need to be in each leaf, and n_estimators tells the algorithim how many trees to make.

# %%
#building a penalized logistic regression model with l2 for ridge
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
kfold = KFold(n_splits=5)
pen_logreg = LogisticRegression(penalty = 'l2').fit(prediction_input_preprocessor.transform(X_train), y_train)
print("Training set score: {:.2f}".format(pen_logreg.score(prediction_input_preprocessor.transform(X_train), y_train)))
print("Test set score: {:.2f}".format(pen_logreg.score(prediction_input_preprocessor.transform(X_test), y_test))) 
print("Mean Cross Validation, KFold: {:.2f}".format(np.mean(cross_val_score(pen_logreg,prediction_input_preprocessor.transform(X_train), y_train, cv=kfold))))
# Out:
# Training set score: 0.72
# Test set score: 0.46
# Mean Cross Validation, KFold: 0.56

# %% [markdown]
# **note Looking at the test score, theres definitely some over tuning**

# %%
#trying to stop warnings from popping up, it failed
import warnings
warnings.simplefilter(action='ignore', category=DeprecationWarning)
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}
grid = GridSearchCV(LogisticRegression(penalty = 'l2'), param_grid, cv=5)
grid.fit(prediction_input_preprocessor.transform(X_train), y_train)

print("LOGISTIC REGRESSION with BIGRAMS")
print("Best cross-validation score: {:.2f}".format(grid.best_score_))
print("Best parameters: ", grid.best_params_)
# Out:
# LOGISTIC REGRESSION with BIGRAMS
# Best cross-validation score: 0.62
# Best parameters:  {'C': 0.1}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
#adjusting the C parameter
model=pen_logreg = LogisticRegression(penalty = 'l2',C = .1).fit(prediction_input_preprocessor.transform(X_train), y_train)
model.fit(prediction_input_preprocessor.transform(X_train), y_train)
y_pred=model.predict(prediction_input_preprocessor.transform(X_test))

# %%
#evaluating model
modelevalobject=model_eval_metrics(y_test,y_pred,classification="TRUE")
modelevalobject
# Out:
#    accuracy  f1_score  precision    recall  mse  rmse  mae  r2
# 0  0.435897  0.430737   0.508442  0.463889    0     0    0   0

# %% [markdown]
# **Answer** the C paramter adjusts the regularization of the function, which controls how much coeffecients that aren't as predictive contribute to the classification

# %%
#building a keras neural net
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import keras
from keras.optimizers import SGD
model = Sequential()
model.add(Dense(11, input_dim=11, activation='relu'))
model.add(Dense(11, activation='relu'))
model.add(Dense(11, activation='relu'))

model.add(Dense(5, activation='softmax')) 
                                            
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
model.fit(prediction_input_preprocessor.transform(X_train), pd.get_dummies(y_train), 
               batch_size = 60, 

               epochs = 50, validation_split=0.2)
# Out:
# Train on 93 samples, validate on 24 samples
# Epoch 1/50
# 93/93 [==============================] - 0s 2ms/step - loss: 1.6008 - acc: 0.2258 - val_loss: 1.5990 - val_acc: 0.2917
# Epoch 2/50
# 93/93 [==============================] - 0s 74us/step - loss: 1.5985 - acc: 0.2366 - val_loss: 1.5976 - val_acc: 0.3333
# Epoch 3/50
# 93/93 [==============================] - 0s 72us/step - loss: 1.5961 - acc: 0.2366 - val_loss: 1.5960 - val_acc: 0.3333
# Epoch 4/50
# 93/93 [==============================] - 0s 67us/step - loss: 1.5936 - acc: 0.2688 - val_loss: 1.5946 - val_acc: 0.3333
# Epoch 5/50
# 93/93 [==============================] - 0s 93us/step - loss: 1.5911 - acc: 0.2688 - val_loss: 1.5931 - val_acc: 0.3333
# Epoch 6/50
# 93/93 [==============================] - 0s 97us/step - loss: 1.5891 - acc: 0.2688 - val_loss: 1.5917 - val_acc: 0.3333
# Epoch 7/50
# 93/93 [==============================] - 0s 95us/step - loss: 1.5864 - acc: 0.2796 - val_loss: 1.5903 - val_acc: 0.3333
# Epoch 8/50
# 93/93 [==============================] - 0s 112us/step - loss: 1.5842 - acc: 0.2688 - val_loss: 1.5890 - val_acc: 0.3333
# Epoch 9/50
# 93/93 [==============================] - 0s 114us/step - loss: 1.5820 - acc: 0.2581 - val_loss: 1.5874 - val_acc: 0.3333
# Epoch 10/50
# 93/93 [==============================] - 0s 116us/step - loss: 1.5797 - acc: 0.2581 - val_loss: 1.5859 - val_acc: 0.3333
# Epoch 11/50
# 93/93 [==============================] - 0s 116us/step - loss: 1.5776 - acc: 0.2581 - val_loss: 1.5843 - val_acc: 0.3333
# Epoch 12/50
# 93/93 [==============================] - 0s 80us/step - loss: 1.5752 - acc: 0.2581 - val_loss: 1.5829 - val_acc: 0.2917
# Epoch 13/50
# 93/93 [==============================] - 0s 65us/step - loss: 1.5729 - acc: 0.2581 - val_loss: 1.5814 - val_acc: 0.2917
# Epoch 14/50
# 93/93 [==============================] - 0s 77us/step - loss: 1.5707 - acc: 0.2581 - val_loss: 1.5800 - val_acc: 0.2917
# Epoch 15/50
# 93/93 [==============================] - 0s 78us/step - loss: 1.5683 - acc: 0.2581 - val_loss: 1.5786 - val_acc: 0.2917
# Epoch 16/50
# 93/93 [==============================] - 0s 82us/step - loss: 1.5662 - acc: 0.2581 - val_loss: 1.5773 - val_acc: 0.2917
# Epoch 17/50
# 93/93 [==============================] - 0s 84us/step - loss: 1.5637 - acc: 0.2581 - val_loss: 1.5758 - val_acc: 0.2917
# Epoch 18/50
# 93/93 [==============================] - 0s 90us/step - loss: 1.5614 - acc: 0.2581 - val_loss: 1.5742 - val_acc: 0.2917
# Epoch 19/50
# 93/93 [==============================] - 0s 90us/step - loss: 1.5591 - acc: 0.2581 - val_loss: 1.5728 - val_acc: 0.2917
# Epoch 20/50
# 93/93 [==============================] - 0s 77us/step - loss: 1.5567 - acc: 0.2581 - val_loss: 1.5713 - val_acc: 0.2917
# Epoch 21/50
# 93/93 [==============================] - 0s 77us/step - loss: 1.5542 - acc: 0.2581 - val_loss: 1.5698 - val_acc: 0.2917
# Epoch 22/50
# 93/93 [==============================] - 0s 86us/step - loss: 1.5520 - acc: 0.2688 - val_loss: 1.5683 - val_acc: 0.2917
# Epoch 23/50
# 93/93 [==============================] - 0s 81us/step - loss: 1.5495 - acc: 0.2581 - val_loss: 1.5667 - val_acc: 0.2917
# Epoch 24/50
# 93/93 [==============================] - 0s 78us/step - loss: 1.5467 - acc: 0.2473 - val_loss: 1.5652 - val_acc: 0.2500
# Epoch 25/50
# 93/93 [==============================] - 0s 74us/step - loss: 1.5440 - acc: 0.2473 - val_loss: 1.5634 - val_acc: 0.2500
# Epoch 26/50
# 93/93 [==============================] - 0s 71us/step - loss: 1.5416 - acc: 0.2473 - val_loss: 1.5617 - val_acc: 0.2500
# Epoch 27/50
# 93/93 [==============================] - 0s 91us/step - loss: 1.5392 - acc: 0.2473 - val_loss: 1.5600 - val_acc: 0.2500
# Epoch 28/50
# 93/93 [==============================] - 0s 78us/step - loss: 1.5367 - acc: 0.2473 - val_loss: 1.5582 - val_acc: 0.2500
# Epoch 29/50
# 93/93 [==============================] - 0s 78us/step - loss: 1.5343 - acc: 0.2473 - val_loss: 1.5562 - val_acc: 0.2500
# Epoch 30/50
# 93/93 [==============================] - 0s 73us/step - loss: 1.5318 - acc: 0.2473 - val_loss: 1.5545 - val_acc: 0.2500
# Epoch 31/50
# 93/93 [==============================] - 0s 81us/step - loss: 1.5292 - acc: 0.2473 - val_loss: 1.5526 - val_acc: 0.2083
# Epoch 32/50
# 93/93 [==============================] - 0s 75us/step - loss: 1.5265 - acc: 0.2473 - val_loss: 1.5506 - val_acc: 0.2083
# Epoch 33/50
# 93/93 [==============================] - 0s 90us/step - loss: 1.5240 - acc: 0.2473 - val_loss: 1.5487 - val_acc: 0.2083
# Epoch 34/50
# 93/93 [==============================] - 0s 92us/step - loss: 1.5210 - acc: 0.2581 - val_loss: 1.5467 - val_acc: 0.2083
# Epoch 35/50
# 93/93 [==============================] - 0s 99us/step - loss: 1.5182 - acc: 0.2581 - val_loss: 1.5448 - val_acc: 0.2083
# Epoch 36/50
# 93/93 [==============================] - 0s 101us/step - loss: 1.5155 - acc: 0.2473 - val_loss: 1.5426 - val_acc: 0.2083
# Epoch 37/50
# 93/93 [==============================] - 0s 92us/step - loss: 1.5126 - acc: 0.2366 - val_loss: 1.5406 - val_acc: 0.2083
# Epoch 38/50
# 93/93 [==============================] - 0s 90us/step - loss: 1.5096 - acc: 0.2366 - val_loss: 1.5386 - val_acc: 0.1667
# Epoch 39/50
# 93/93 [==============================] - 0s 90us/step - loss: 1.5068 - acc: 0.2473 - val_loss: 1.5365 - val_acc: 0.1667
# Epoch 40/50
# 93/93 [==============================] - 0s 114us/step - loss: 1.5041 - acc: 0.2473 - val_loss: 1.5343 - val_acc: 0.1667
# Epoch 41/50
# 93/93 [==============================] - 0s 106us/step - loss: 1.5013 - acc: 0.2473 - val_loss: 1.5320 - val_acc: 0.1667
# Epoch 42/50
# 93/93 [==============================] - 0s 92us/step - loss: 1.4982 - acc: 0.2473 - val_loss: 1.5299 - val_acc: 0.1667
# Epoch 43/50
# 93/93 [==============================] - 0s 87us/step - loss: 1.4954 - acc: 0.2366 - val_loss: 1.5276 - val_acc: 0.1667
# Epoch 44/50
# 93/93 [==============================] - 0s 88us/step - loss: 1.4925 - acc: 0.2366 - val_loss: 1.5254 - val_acc: 0.1667
# Epoch 45/50
# 93/93 [==============================] - 0s 108us/step - loss: 1.4897 - acc: 0.2473 - val_loss: 1.5233 - val_acc: 0.1667
# Epoch 46/50
# 93/93 [==============================] - 0s 102us/step - loss: 1.4870 - acc: 0.2473 - val_loss: 1.5211 - val_acc: 0.1667
# Epoch 47/50
# 93/93 [==============================] - 0s 77us/step - loss: 1.4841 - acc: 0.2473 - val_loss: 1.5188 - val_acc: 0.1667
# Epoch 48/50
# 93/93 [==============================] - 0s 78us/step - loss: 1.4814 - acc: 0.2688 - val_loss: 1.5165 - val_acc: 0.1667
# Epoch 49/50
# 93/93 [==============================] - 0s 79us/step - loss: 1.4786 - acc: 0.2581 - val_loss: 1.5145 - val_acc: 0.1667
# Epoch 50/50
# 93/93 [==============================] - 0s 90us/step - loss: 1.4758 - acc: 0.2688 - val_loss: 1.5123 - val_acc: 0.1667

# %%
model_eval_metrics( y_test,predicted_labels,classification="TRUE")
# Out:
#    accuracy  f1_score  precision  recall  mse  rmse  mae  r2
# 0  0.230769  0.130303      0.114   0.225    0     0    0   0

# %%
#Creating a model to perform cross validation
def create_model():
	# create model
  model = Sequential()
  model.add(Dense(11, input_dim=11, activation='relu'))
  model.add(Dense(11, activation='relu'))
  model.add(Dense(11, activation='relu'))
  model.add(Dense(5, activation='softmax'))                                          
  # Compile model
  model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
  return model

model = KerasClassifier(build_fn=create_model, epochs=100, verbose=0)

# %%
#tuning the number of epochs
param_grid = dict(epochs=[500,600,700])
grid = GridSearchCV(estimator=model, param_grid=param_grid)
grid_result = grid.fit(prediction_input_preprocessor.transform(X_train), pd.get_dummies(y_train))
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.625725 using {'epochs': 600}

# %%
#tuning the number of epochs again
param_grid = dict(epochs=[700,800,900])
grid = GridSearchCV(estimator=model, param_grid=param_grid)
grid_result = grid.fit(prediction_input_preprocessor.transform(X_train), pd.get_dummies(y_train))
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.573551 using {'epochs': 800}

# %%
#creating another model to perform cross validation
def create_model(learn_rate=0.01):
	# create model
  model = Sequential()
  model.add(Dense(11, input_dim=11, activation='relu'))
  model.add(Dense(11, activation='relu'))
  model.add(Dense(5, activation='softmax'))                                          
  # Compile model
  optimizer = SGD(lr=learn_rate)
  model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
  return model

#call model function in KerasClassifier
model = KerasClassifier(build_fn=create_model, epochs=600, verbose=0)

learn_rate = [0.0001,0.001, 0.01,.1,1]
param_grid = dict(learn_rate=learn_rate)

grid = GridSearchCV(estimator=model, param_grid=param_grid)
grid_result = grid.fit(prediction_input_preprocessor.transform(X_train), pd.get_dummies(y_train))

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.555435 using {'learn_rate': 0.01}

# %%
#Running final keras model with tweaked paramaters
from keras import optimizers
model = Sequential()
model.add(Dense(13, input_dim=11, activation='relu'))
model.add(Dense(7, activation='relu'))
model.add(Dense(5, activation='softmax')) 
                              
# Compile model
sgd = optimizers.SGD(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=sgd)

# Fitting the NN to the Training set
model.fit(prediction_input_preprocessor.transform(X_train), pd.get_dummies(y_train), 
               batch_size = 25, 

               epochs = 700, validation_split=0.2)
# Out:
# Train on 93 samples, validate on 24 samples
# Epoch 1/700
# 93/93 [==============================] - 3s 36ms/step - loss: 1.6328 - val_loss: 1.5244
# Epoch 2/700
# 93/93 [==============================] - 0s 196us/step - loss: 1.6224 - val_loss: 1.5159
# Epoch 3/700
# 93/93 [==============================] - 0s 137us/step - loss: 1.6122 - val_loss: 1.5082
# Epoch 4/700
# 93/93 [==============================] - 0s 143us/step - loss: 1.6027 - val_loss: 1.5005
# Epoch 5/700
# 93/93 [==============================] - 0s 157us/step - loss: 1.5935 - val_loss: 1.4936
# Epoch 6/700
# 93/93 [==============================] - 0s 168us/step - loss: 1.5854 - val_loss: 1.4869
# Epoch 7/700
# 93/93 [==============================] - 0s 151us/step - loss: 1.5770 - val_loss: 1.4808
# Epoch 8/700
# 93/93 [==============================] - 0s 152us/step - loss: 1.5695 - val_loss: 1.4750
# Epoch 9/700
# 93/93 [==============================] - 0s 167us/step - loss: 1.5625 - val_loss: 1.4696
# Epoch 10/700
# 93/93 [==============================] - 0s 145us/step - loss: 1.5558 - val_loss: 1.4641
# Epoch 11/700
# 93/93 [==============================] - 0s 137us/step - loss: 1.5491 - val_loss: 1.4590
# Epoch 12/700
# 93/93 [==============================] - 0s 157us/step - loss: 1.5423 - val_loss: 1.4545
# Epoch 13/700
# 93/93 [==============================] - 0s 163us/step - loss: 1.5365 - val_loss: 1.4502
# Epoch 14/700
# 93/93 [==============================] - 0s 192us/step - loss: 1.5311 - val_loss: 1.4460
# Epoch 15/700
# 93/93 [==============================] - 0s 153us/step - loss: 1.5250 - val_loss: 1.4417
# Epoch 16/700
# 93/93 [==============================] - 0s 167us/step - loss: 1.5195 - val_loss: 1.4380
# Epoch 17/700
# 93/93 [==============================] - 0s 156us/step - loss: 1.5139 - val_loss: 1.4340
# Epoch 18/700
# 93/93 [==============================] - 0s 160us/step - loss: 1.5081 - val_loss: 1.4297
# Epoch 19/700
# 93/93 [==============================] - 0s 194us/step - loss: 1.5027 - val_loss: 1.4258
# Epoch 20/700
# 93/93 [==============================] - 0s 185us/step - loss: 1.4976 - val_loss: 1.4222
# Epoch 21/700
# 93/93 [==============================] - 0s 141us/step - loss: 1.4921 - val_loss: 1.4188
# Epoch 22/700
# 93/93 [==============================] - 0s 185us/step - loss: 1.4870 - val_loss: 1.4153
# Epoch 23/700
# 93/93 [==============================] - 0s 161us/step - loss: 1.4816 - val_loss: 1.4120
# Epoch 24/700
# 93/93 [==============================] - 0s 180us/step - loss: 1.4764 - val_loss: 1.4088
# Epoch 25/700
# 93/93 [==============================] - 0s 195us/step - loss: 1.4715 - val_loss: 1.4057
# Epoch 26/700
# 93/93 [==============================] - 0s 151us/step - loss: 1.4663 - val_loss: 1.4023
# Epoch 27/700
# 93/93 [==============================] - 0s 148us/step - loss: 1.4609 - val_loss: 1.3990
# Epoch 28/700
# 93/93 [==============================] - 0s 170us/step - loss: 1.4562 - val_loss: 1.3959
# Epoch 29/700
# 93/93 [==============================] - 0s 137us/step - loss: 1.4515 - val_loss: 1.3924
# Epoch 30/700
# 93/93 [==============================] - 0s 159us/step - loss: 1.4458 - val_loss: 1.3889
# Epoch 31/700
# 93/93 [==============================] - 0s 141us/step - loss: 1.4406 - val_loss: 1.3856
# Epoch 32/700
# 93/93 [==============================] - 0s 170us/step - loss: 1.4355 - val_loss: 1.3819
# Epoch 33/700
# 93/93 [==============================] - 0s 160us/step - loss: 1.4298 - val_loss: 1.3785
# Epoch 34/700
# 93/93 [==============================] - 0s 145us/step - loss: 1.4249 - val_loss: 1.3750
# Epoch 35/700
# 93/93 [==============================] - 0s 181us/step - loss: 1.4191 - val_loss: 1.3714
# Epoch 36/700
# 93/93 [==============================] - 0s 166us/step - loss: 1.4136 - val_loss: 1.3677
# Epoch 37/700
# 93/93 [==============================] - 0s 157us/step - loss: 1.4086 - val_loss: 1.3643
# Epoch 38/700
# 93/93 [==============================] - 0s 182us/step - loss: 1.4029 - val_loss: 1.3607
# Epoch 39/700
# 93/93 [==============================] - 0s 178us/step - loss: 1.3973 - val_loss: 1.3568
# Epoch 40/700
# 93/93 [==============================] - 0s 201us/step - loss: 1.3916 - val_loss: 1.3529
# Epoch 41/700
# 93/93 [==============================] - 0s 159us/step - loss: 1.3860 - val_loss: 1.3491
# Epoch 42/700
# 93/93 [==============================] - 0s 149us/step - loss: 1.3806 - val_loss: 1.3454
# Epoch 43/700
# 93/93 [==============================] - 0s 167us/step - loss: 1.3744 - val_loss: 1.3417
# Epoch 44/700
# 93/93 [==============================] - 0s 159us/step - loss: 1.3691 - val_loss: 1.3381
# Epoch 45/700
# 93/93 [==============================] - 0s 131us/step - loss: 1.3635 - val_loss: 1.3342
# Epoch 46/700
# 93/93 [==============================] - 0s 147us/step - loss: 1.3573 - val_loss: 1.3303
# Epoch 47/700
# 93/93 [==============================] - 0s 143us/step - loss: 1.3518 - val_loss: 1.3265
# Epoch 48/700
# 93/93 [==============================] - 0s 168us/step - loss: 1.3460 - val_loss: 1.3226
# Epoch 49/700
# 93/93 [==============================] - 0s 140us/step - loss: 1.3409 - val_loss: 1.3188
# Epoch 50/700
# 93/93 [==============================] - 0s 224us/step - loss: 1.3347 - val_loss: 1.3148
# Epoch 51/700
# 93/93 [==============================] - 0s 229us/step - loss: 1.3291 - val_loss: 1.3109
# Epoch 52/700
# 93/93 [==============================] - 0s 252us/step - loss: 1.3232 - val_loss: 1.3067
# Epoch 53/700
# 93/93 [==============================] - 0s 196us/step - loss: 1.3180 - val_loss: 1.3024
# Epoch 54/700
# 93/93 [==============================] - 0s 163us/step - loss: 1.3118 - val_loss: 1.2980
# Epoch 55/700
# 93/93 [==============================] - 0s 161us/step - loss: 1.3061 - val_loss: 1.2937
# Epoch 56/700
# 93/93 [==============================] - 0s 158us/step - loss: 1.3005 - val_loss: 1.2894
# Epoch 57/700
# 93/93 [==============================] - 0s 152us/step - loss: 1.2948 - val_loss: 1.2851
# Epoch 58/700
# 93/93 [==============================] - 0s 146us/step - loss: 1.2891 - val_loss: 1.2807
# Epoch 59/700
# 93/93 [==============================] - 0s 143us/step - loss: 1.2838 - val_loss: 1.2764
# Epoch 60/700
# 93/93 [==============================] - 0s 152us/step - loss: 1.2770 - val_loss: 1.2719
# Epoch 61/700
# 93/93 [==============================] - 0s 175us/step - loss: 1.2716 - val_loss: 1.2675
# Epoch 62/700
# 93/93 [==============================] - 0s 140us/step - loss: 1.2653 - val_loss: 1.2631
# Epoch 63/700
# 93/93 [==============================] - 0s 157us/step - loss: 1.2597 - val_loss: 1.2587
# Epoch 64/700
# 93/93 [==============================] - 0s 148us/step - loss: 1.2535 - val_loss: 1.2542
# Epoch 65/700
# 93/93 [==============================] - 0s 195us/step - loss: 1.2477 - val_loss: 1.2498
# Epoch 66/700
# 93/93 [==============================] - 0s 146us/step - loss: 1.2417 - val_loss: 1.2456
# Epoch 67/700
# 93/93 [==============================] - 0s 238us/step - loss: 1.2360 - val_loss: 1.2414
# Epoch 68/700
# 93/93 [==============================] - 0s 151us/step - loss: 1.2299 - val_loss: 1.2372
# Epoch 69/700
# 93/93 [==============================] - 0s 202us/step - loss: 1.2240 - val_loss: 1.2330
# Epoch 70/700
# 93/93 [==============================] - 0s 157us/step - loss: 1.2181 - val_loss: 1.2288
# Epoch 71/700
# 93/93 [==============================] - 0s 217us/step - loss: 1.2120 - val_loss: 1.2245
# Epoch 72/700
# 93/93 [==============================] - 0s 171us/step - loss: 1.2069 - val_loss: 1.2205
# Epoch 73/700
# 93/93 [==============================] - 0s 174us/step - loss: 1.2005 - val_loss: 1.2163
# Epoch 74/700
# 93/93 [==============================] - 0s 178us/step - loss: 1.1945 - val_loss: 1.2121
# Epoch 75/700
# 93/93 [==============================] - 0s 194us/step - loss: 1.1889 - val_loss: 1.2081
# Epoch 76/700
# 93/93 [==============================] - 0s 181us/step - loss: 1.1834 - val_loss: 1.2040
# Epoch 77/700
# 93/93 [==============================] - 0s 199us/step - loss: 1.1775 - val_loss: 1.2000
# Epoch 78/700
# 93/93 [==============================] - 0s 169us/step - loss: 1.1717 - val_loss: 1.1961
# Epoch 79/700
# 93/93 [==============================] - 0s 147us/step - loss: 1.1661 - val_loss: 1.1919
# Epoch 80/700
# 93/93 [==============================] - 0s 137us/step - loss: 1.1607 - val_loss: 1.1880
# Epoch 81/700
# 93/93 [==============================] - 0s 188us/step - loss: 1.1550 - val_loss: 1.1840
# Epoch 82/700
# 93/93 [==============================] - 0s 140us/step - loss: 1.1494 - val_loss: 1.1801
# Epoch 83/700
# 93/93 [==============================] - 0s 141us/step - loss: 1.1439 - val_loss: 1.1760
# Epoch 84/700
# 93/93 [==============================] - 0s 123us/step - loss: 1.1385 - val_loss: 1.1722
# Epoch 85/700
# 93/93 [==============================] - 0s 123us/step - loss: 1.1339 - val_loss: 1.1684
# Epoch 86/700
# 93/93 [==============================] - 0s 159us/step - loss: 1.1286 - val_loss: 1.1646
# Epoch 87/700
# 93/93 [==============================] - 0s 147us/step - loss: 1.1232 - val_loss: 1.1609
# Epoch 88/700
# 93/93 [==============================] - 0s 164us/step - loss: 1.1179 - val_loss: 1.1573
# Epoch 89/700
# 93/93 [==============================] - 0s 159us/step - loss: 1.1130 - val_loss: 1.1535
# Epoch 90/700
# 93/93 [==============================] - 0s 145us/step - loss: 1.1074 - val_loss: 1.1497
# Epoch 91/700
# 93/93 [==============================] - 0s 132us/step - loss: 1.1028 - val_loss: 1.1461
# Epoch 92/700
# 93/93 [==============================] - 0s 193us/step - loss: 1.0976 - val_loss: 1.1423
# Epoch 93/700
# 93/93 [==============================] - 0s 153us/step - loss: 1.0935 - val_loss: 1.1389
# Epoch 94/700
# 93/93 [==============================] - 0s 125us/step - loss: 1.0881 - val_loss: 1.1354
# Epoch 95/700
# 93/93 [==============================] - 0s 130us/step - loss: 1.0830 - val_loss: 1.1320
# Epoch 96/700
# 93/93 [==============================] - 0s 173us/step - loss: 1.0783 - val_loss: 1.1287
# Epoch 97/700
# 93/93 [==============================] - 0s 150us/step - loss: 1.0741 - val_loss: 1.1257
# Epoch 98/700
# 93/93 [==============================] - 0s 133us/step - loss: 1.0695 - val_loss: 1.1224
# Epoch 99/700
# 93/93 [==============================] - 0s 127us/step - loss: 1.0656 - val_loss: 1.1193
# Epoch 100/700
# 93/93 [==============================] - 0s 168us/step - loss: 1.0605 - val_loss: 1.1163
# Epoch 101/700
# 93/93 [==============================] - 0s 154us/step - loss: 1.0567 - val_loss: 1.1132
# Epoch 102/700
# 93/93 [==============================] - 0s 131us/step - loss: 1.0516 - val_loss: 1.1102
# Epoch 103/700
# 93/93 [==============================] - 0s 152us/step - loss: 1.0478 - val_loss: 1.1073
# Epoch 104/700
# 93/93 [==============================] - 0s 157us/step - loss: 1.0435 - val_loss: 1.1044
# Epoch 105/700
# 93/93 [==============================] - 0s 158us/step - loss: 1.0393 - val_loss: 1.1014
# Epoch 106/700
# 93/93 [==============================] - 0s 215us/step - loss: 1.0357 - val_loss: 1.0984
# Epoch 107/700
# 93/93 [==============================] - 0s 204us/step - loss: 1.0307 - val_loss: 1.0956
# Epoch 108/700
# 93/93 [==============================] - 0s 158us/step - loss: 1.0267 - val_loss: 1.0930
# Epoch 109/700
# 93/93 [==============================] - 0s 166us/step - loss: 1.0230 - val_loss: 1.0904
# Epoch 110/700
# 93/93 [==============================] - 0s 152us/step - loss: 1.0199 - val_loss: 1.0880
# Epoch 111/700
# 93/93 [==============================] - 0s 182us/step - loss: 1.0150 - val_loss: 1.0856
# Epoch 112/700
# 93/93 [==============================] - 0s 147us/step - loss: 1.0113 - val_loss: 1.0833
# Epoch 113/700
# 93/93 [==============================] - 0s 143us/step - loss: 1.0085 - val_loss: 1.0810
# Epoch 114/700
# 93/93 [==============================] - 0s 176us/step - loss: 1.0049 - val_loss: 1.0787
# Epoch 115/700
# 93/93 [==============================] - 0s 197us/step - loss: 1.0001 - val_loss: 1.0764
# Epoch 116/700
# 93/93 [==============================] - 0s 199us/step - loss: 0.9972 - val_loss: 1.0742
# Epoch 117/700
# 93/93 [==============================] - 0s 162us/step - loss: 0.9941 - val_loss: 1.0720
# Epoch 118/700
# 93/93 [==============================] - 0s 197us/step - loss: 0.9900 - val_loss: 1.0700
# Epoch 119/700
# 93/93 [==============================] - 0s 155us/step - loss: 0.9870 - val_loss: 1.0681
# Epoch 120/700
# 93/93 [==============================] - 0s 164us/step - loss: 0.9834 - val_loss: 1.0659
# Epoch 121/700
# 93/93 [==============================] - 0s 163us/step - loss: 0.9796 - val_loss: 1.0641
# Epoch 122/700
# 93/93 [==============================] - 0s 168us/step - loss: 0.9762 - val_loss: 1.0621
# Epoch 123/700
# 93/93 [==============================] - 0s 157us/step - loss: 0.9732 - val_loss: 1.0600
# Epoch 124/700
# 93/93 [==============================] - 0s 156us/step - loss: 0.9701 - val_loss: 1.0583
# Epoch 125/700
# 93/93 [==============================] - 0s 191us/step - loss: 0.9666 - val_loss: 1.0563
# Epoch 126/700
# 93/93 [==============================] - 0s 126us/step - loss: 0.9643 - val_loss: 1.0545
# Epoch 127/700
# 93/93 [==============================] - 0s 139us/step - loss: 0.9604 - val_loss: 1.0526
# Epoch 128/700
# 93/93 [==============================] - 0s 256us/step - loss: 0.9583 - val_loss: 1.0508
# Epoch 129/700
# 93/93 [==============================] - 0s 176us/step - loss: 0.9543 - val_loss: 1.0490
# Epoch 130/700
# 93/93 [==============================] - 0s 164us/step - loss: 0.9520 - val_loss: 1.0473
# Epoch 131/700
# 93/93 [==============================] - 0s 200us/step - loss: 0.9492 - val_loss: 1.0457
# Epoch 132/700
# 93/93 [==============================] - 0s 201us/step - loss: 0.9459 - val_loss: 1.0440
# Epoch 133/700
# 93/93 [==============================] - 0s 169us/step - loss: 0.9432 - val_loss: 1.0427
# Epoch 134/700
# 93/93 [==============================] - 0s 179us/step - loss: 0.9399 - val_loss: 1.0410
# Epoch 135/700
# 93/93 [==============================] - 0s 156us/step - loss: 0.9375 - val_loss: 1.0396
# Epoch 136/700
# 93/93 [==============================] - 0s 148us/step - loss: 0.9351 - val_loss: 1.0379
# Epoch 137/700
# 93/93 [==============================] - 0s 163us/step - loss: 0.9323 - val_loss: 1.0367
# Epoch 138/700
# 93/93 [==============================] - 0s 131us/step - loss: 0.9303 - val_loss: 1.0353
# Epoch 139/700
# 93/93 [==============================] - 0s 118us/step - loss: 0.9267 - val_loss: 1.0337
# Epoch 140/700
# 93/93 [==============================] - 0s 122us/step - loss: 0.9237 - val_loss: 1.0324
# Epoch 141/700
# 93/93 [==============================] - 0s 141us/step - loss: 0.9219 - val_loss: 1.0309
# Epoch 142/700
# 93/93 [==============================] - 0s 160us/step - loss: 0.9192 - val_loss: 1.0296
# Epoch 143/700
# 93/93 [==============================] - 0s 173us/step - loss: 0.9178 - val_loss: 1.0284
# Epoch 144/700
# 93/93 [==============================] - 0s 133us/step - loss: 0.9150 - val_loss: 1.0270
# Epoch 145/700
# 93/93 [==============================] - 0s 118us/step - loss: 0.9117 - val_loss: 1.0258
# Epoch 146/700
# 93/93 [==============================] - 0s 140us/step - loss: 0.9095 - val_loss: 1.0247
# Epoch 147/700
# 93/93 [==============================] - 0s 131us/step - loss: 0.9077 - val_loss: 1.0237
# Epoch 148/700
# 93/93 [==============================] - 0s 160us/step - loss: 0.9051 - val_loss: 1.0226
# Epoch 149/700
# 93/93 [==============================] - 0s 144us/step - loss: 0.9025 - val_loss: 1.0215
# Epoch 150/700
# 93/93 [==============================] - 0s 161us/step - loss: 0.9016 - val_loss: 1.0207
# Epoch 151/700
# 93/93 [==============================] - 0s 161us/step - loss: 0.8979 - val_loss: 1.0198
# Epoch 152/700
# 93/93 [==============================] - 0s 166us/step - loss: 0.8969 - val_loss: 1.0190
# Epoch 153/700
# 93/93 [==============================] - 0s 149us/step - loss: 0.8945 - val_loss: 1.0184
# Epoch 154/700
# 93/93 [==============================] - 0s 158us/step - loss: 0.8920 - val_loss: 1.0179
# Epoch 155/700
# 93/93 [==============================] - 0s 242us/step - loss: 0.8909 - val_loss: 1.0169
# Epoch 156/700
# 93/93 [==============================] - 0s 247us/step - loss: 0.8874 - val_loss: 1.0162
# Epoch 157/700
# 93/93 [==============================] - 0s 223us/step - loss: 0.8855 - val_loss: 1.0154
# Epoch 158/700
# 93/93 [==============================] - 0s 187us/step - loss: 0.8833 - val_loss: 1.0146
# Epoch 159/700
# 93/93 [==============================] - 0s 186us/step - loss: 0.8814 - val_loss: 1.0143
# Epoch 160/700
# 93/93 [==============================] - 0s 179us/step - loss: 0.8805 - val_loss: 1.0137
# Epoch 161/700
# 93/93 [==============================] - 0s 222us/step - loss: 0.8778 - val_loss: 1.0131
# Epoch 162/700
# 93/93 [==============================] - 0s 185us/step - loss: 0.8761 - val_loss: 1.0129
# Epoch 163/700
# 93/93 [==============================] - 0s 178us/step - loss: 0.8745 - val_loss: 1.0123
# Epoch 164/700
# 93/93 [==============================] - 0s 158us/step - loss: 0.8722 - val_loss: 1.0118
# Epoch 165/700
# 93/93 [==============================] - 0s 180us/step - loss: 0.8702 - val_loss: 1.0110
# Epoch 166/700
# 93/93 [==============================] - 0s 160us/step - loss: 0.8689 - val_loss: 1.0105
# Epoch 167/700
# 93/93 [==============================] - 0s 160us/step - loss: 0.8667 - val_loss: 1.0103
# Epoch 168/700
# 93/93 [==============================] - 0s 145us/step - loss: 0.8651 - val_loss: 1.0097
# Epoch 169/700
# 93/93 [==============================] - 0s 210us/step - loss: 0.8629 - val_loss: 1.0092
# Epoch 170/700
# 93/93 [==============================] - 0s 149us/step - loss: 0.8616 - val_loss: 1.0087
# Epoch 171/700
# 93/93 [==============================] - 0s 195us/step - loss: 0.8596 - val_loss: 1.0080
# Epoch 172/700
# 93/93 [==============================] - 0s 209us/step - loss: 0.8576 - val_loss: 1.0077
# Epoch 173/700
# 93/93 [==============================] - 0s 164us/step - loss: 0.8562 - val_loss: 1.0073
# Epoch 174/700
# 93/93 [==============================] - 0s 180us/step - loss: 0.8551 - val_loss: 1.0066
# Epoch 175/700
# 93/93 [==============================] - 0s 169us/step - loss: 0.8535 - val_loss: 1.0059
# Epoch 176/700
# 93/93 [==============================] - 0s 162us/step - loss: 0.8517 - val_loss: 1.0060
# Epoch 177/700
# 93/93 [==============================] - 0s 211us/step - loss: 0.8497 - val_loss: 1.0054
# Epoch 178/700
# 93/93 [==============================] - 0s 192us/step - loss: 0.8483 - val_loss: 1.0051
# Epoch 179/700
# 93/93 [==============================] - 0s 147us/step - loss: 0.8470 - val_loss: 1.0050
# Epoch 180/700
# 93/93 [==============================] - 0s 185us/step - loss: 0.8467 - val_loss: 1.0041
# Epoch 181/700
# 93/93 [==============================] - 0s 148us/step - loss: 0.8432 - val_loss: 1.0041
# Epoch 182/700
# 93/93 [==============================] - 0s 146us/step - loss: 0.8419 - val_loss: 1.0041
# Epoch 183/700
# 93/93 [==============================] - 0s 204us/step - loss: 0.8409 - val_loss: 1.0042
# Epoch 184/700
# 93/93 [==============================] - 0s 172us/step - loss: 0.8396 - val_loss: 1.0038
# Epoch 185/700
# 93/93 [==============================] - 0s 180us/step - loss: 0.8375 - val_loss: 1.0038
# Epoch 186/700
# 93/93 [==============================] - 0s 167us/step - loss: 0.8367 - val_loss: 1.0040
# Epoch 187/700
# 93/93 [==============================] - 0s 167us/step - loss: 0.8349 - val_loss: 1.0039
# Epoch 188/700
# 93/93 [==============================] - 0s 173us/step - loss: 0.8332 - val_loss: 1.0040
# Epoch 189/700
# 93/93 [==============================] - 0s 140us/step - loss: 0.8317 - val_loss: 1.0038
# Epoch 190/700
# 93/93 [==============================] - 0s 181us/step - loss: 0.8299 - val_loss: 1.0035
# Epoch 191/700
# 93/93 [==============================] - 0s 151us/step - loss: 0.8287 - val_loss: 1.0032
# Epoch 192/700
# 93/93 [==============================] - 0s 198us/step - loss: 0.8274 - val_loss: 1.0032
# Epoch 193/700
# 93/93 [==============================] - 0s 192us/step - loss: 0.8260 - val_loss: 1.0033
# Epoch 194/700
# 93/93 [==============================] - 0s 159us/step - loss: 0.8251 - val_loss: 1.0037
# Epoch 195/700
# 93/93 [==============================] - 0s 145us/step - loss: 0.8239 - val_loss: 1.0031
# Epoch 196/700
# 93/93 [==============================] - 0s 232us/step - loss: 0.8229 - val_loss: 1.0032
# Epoch 197/700
# 93/93 [==============================] - 0s 191us/step - loss: 0.8216 - val_loss: 1.0033
# Epoch 198/700
# 93/93 [==============================] - 0s 163us/step - loss: 0.8188 - val_loss: 1.0031
# Epoch 199/700
# 93/93 [==============================] - 0s 187us/step - loss: 0.8182 - val_loss: 1.0029
# Epoch 200/700
# 93/93 [==============================] - 0s 140us/step - loss: 0.8174 - val_loss: 1.0028
# Epoch 201/700
# 93/93 [==============================] - 0s 240us/step - loss: 0.8156 - val_loss: 1.0031
# Epoch 202/700
# 93/93 [==============================] - 0s 187us/step - loss: 0.8145 - val_loss: 1.0028
# Epoch 203/700
# 93/93 [==============================] - 0s 216us/step - loss: 0.8140 - val_loss: 1.0024
# Epoch 204/700
# 93/93 [==============================] - 0s 208us/step - loss: 0.8127 - val_loss: 1.0022
# Epoch 205/700
# 93/93 [==============================] - 0s 161us/step - loss: 0.8102 - val_loss: 1.0021
# Epoch 206/700
# 93/93 [==============================] - 0s 173us/step - loss: 0.8088 - val_loss: 1.0019
# Epoch 207/700
# 93/93 [==============================] - 0s 137us/step - loss: 0.8076 - val_loss: 1.0023
# Epoch 208/700
# 93/93 [==============================] - 0s 164us/step - loss: 0.8070 - val_loss: 1.0017
# Epoch 209/700
# 93/93 [==============================] - 0s 175us/step - loss: 0.8065 - val_loss: 1.0018
# Epoch 210/700
# 93/93 [==============================] - 0s 170us/step - loss: 0.8043 - val_loss: 1.0017
# Epoch 211/700
# 93/93 [==============================] - 0s 150us/step - loss: 0.8028 - val_loss: 1.0019
# Epoch 212/700
# 93/93 [==============================] - 0s 169us/step - loss: 0.8017 - val_loss: 1.0022
# Epoch 213/700
# 93/93 [==============================] - 0s 184us/step - loss: 0.7999 - val_loss: 1.0024
# Epoch 214/700
# 93/93 [==============================] - 0s 173us/step - loss: 0.8001 - val_loss: 1.0029
# Epoch 215/700
# 93/93 [==============================] - 0s 157us/step - loss: 0.7985 - val_loss: 1.0030
# Epoch 216/700
# 93/93 [==============================] - 0s 156us/step - loss: 0.7977 - val_loss: 1.0033
# Epoch 217/700
# 93/93 [==============================] - 0s 135us/step - loss: 0.7973 - val_loss: 1.0034
# Epoch 218/700
# 93/93 [==============================] - 0s 220us/step - loss: 0.7947 - val_loss: 1.0035
# Epoch 219/700
# 93/93 [==============================] - 0s 174us/step - loss: 0.7936 - val_loss: 1.0037
# Epoch 220/700
# 93/93 [==============================] - 0s 158us/step - loss: 0.7925 - val_loss: 1.0036
# Epoch 221/700
# 93/93 [==============================] - 0s 155us/step - loss: 0.7922 - val_loss: 1.0043
# Epoch 222/700
# 93/93 [==============================] - 0s 178us/step - loss: 0.7909 - val_loss: 1.0046
# Epoch 223/700
# 93/93 [==============================] - 0s 167us/step - loss: 0.7913 - val_loss: 1.0043
# Epoch 224/700
# 93/93 [==============================] - 0s 165us/step - loss: 0.7888 - val_loss: 1.0045
# Epoch 225/700
# 93/93 [==============================] - 0s 150us/step - loss: 0.7877 - val_loss: 1.0051
# Epoch 226/700
# 93/93 [==============================] - 0s 146us/step - loss: 0.7868 - val_loss: 1.0050
# Epoch 227/700
# 93/93 [==============================] - 0s 164us/step - loss: 0.7857 - val_loss: 1.0049
# Epoch 228/700
# 93/93 [==============================] - 0s 178us/step - loss: 0.7851 - val_loss: 1.0049
# Epoch 229/700
# 93/93 [==============================] - 0s 148us/step - loss: 0.7839 - val_loss: 1.0053
# Epoch 230/700
# 93/93 [==============================] - 0s 168us/step - loss: 0.7835 - val_loss: 1.0057
# Epoch 231/700
# 93/93 [==============================] - 0s 163us/step - loss: 0.7817 - val_loss: 1.0059
# Epoch 232/700
# 93/93 [==============================] - 0s 136us/step - loss: 0.7805 - val_loss: 1.0059
# Epoch 233/700
# 93/93 [==============================] - 0s 155us/step - loss: 0.7802 - val_loss: 1.0069
# Epoch 234/700
# 93/93 [==============================] - 0s 157us/step - loss: 0.7789 - val_loss: 1.0072
# Epoch 235/700
# 93/93 [==============================] - 0s 189us/step - loss: 0.7777 - val_loss: 1.0072
# Epoch 236/700
# 93/93 [==============================] - 0s 149us/step - loss: 0.7766 - val_loss: 1.0071
# Epoch 237/700
# 93/93 [==============================] - 0s 131us/step - loss: 0.7770 - val_loss: 1.0078
# Epoch 238/700
# 93/93 [==============================] - 0s 168us/step - loss: 0.7746 - val_loss: 1.0083
# Epoch 239/700
# 93/93 [==============================] - 0s 139us/step - loss: 0.7740 - val_loss: 1.0089
# Epoch 240/700
# 93/93 [==============================] - 0s 165us/step - loss: 0.7726 - val_loss: 1.0090
# Epoch 241/700
# 93/93 [==============================] - 0s 146us/step - loss: 0.7727 - val_loss: 1.0093
# Epoch 242/700
# 93/93 [==============================] - 0s 248us/step - loss: 0.7711 - val_loss: 1.0093
# Epoch 243/700
# 93/93 [==============================] - 0s 173us/step - loss: 0.7700 - val_loss: 1.0087
# Epoch 244/700
# 93/93 [==============================] - 0s 174us/step - loss: 0.7686 - val_loss: 1.0093
# Epoch 245/700
# 93/93 [==============================] - 0s 159us/step - loss: 0.7690 - val_loss: 1.0092
# Epoch 246/700
# 93/93 [==============================] - 0s 177us/step - loss: 0.7679 - val_loss: 1.0097
# Epoch 247/700
# 93/93 [==============================] - 0s 157us/step - loss: 0.7656 - val_loss: 1.0103
# Epoch 248/700
# 93/93 [==============================] - 0s 160us/step - loss: 0.7661 - val_loss: 1.0102
# Epoch 249/700
# 93/93 [==============================] - 0s 184us/step - loss: 0.7644 - val_loss: 1.0103
# Epoch 250/700
# 93/93 [==============================] - 0s 174us/step - loss: 0.7636 - val_loss: 1.0107
# Epoch 251/700
# 93/93 [==============================] - 0s 203us/step - loss: 0.7626 - val_loss: 1.0108
# Epoch 252/700
# 93/93 [==============================] - 0s 227us/step - loss: 0.7617 - val_loss: 1.0115
# Epoch 253/700
# 93/93 [==============================] - 0s 178us/step - loss: 0.7600 - val_loss: 1.0115
# Epoch 254/700
# 93/93 [==============================] - 0s 182us/step - loss: 0.7596 - val_loss: 1.0115
# Epoch 255/700
# 93/93 [==============================] - 0s 170us/step - loss: 0.7587 - val_loss: 1.0119
# Epoch 256/700
# 93/93 [==============================] - 0s 172us/step - loss: 0.7568 - val_loss: 1.0126
# Epoch 257/700
# 93/93 [==============================] - 0s 164us/step - loss: 0.7578 - val_loss: 1.0129
# Epoch 258/700
# 93/93 [==============================] - 0s 135us/step - loss: 0.7561 - val_loss: 1.0139
# Epoch 259/700
# 93/93 [==============================] - 0s 180us/step - loss: 0.7556 - val_loss: 1.0140
# Epoch 260/700
# 93/93 [==============================] - 0s 161us/step - loss: 0.7540 - val_loss: 1.0141
# Epoch 261/700
# 93/93 [==============================] - 0s 167us/step - loss: 0.7536 - val_loss: 1.0144
# Epoch 262/700
# 93/93 [==============================] - 0s 193us/step - loss: 0.7521 - val_loss: 1.0146
# Epoch 263/700
# 93/93 [==============================] - 0s 178us/step - loss: 0.7515 - val_loss: 1.0154
# Epoch 264/700
# 93/93 [==============================] - 0s 253us/step - loss: 0.7516 - val_loss: 1.0159
# Epoch 265/700
# 93/93 [==============================] - 0s 152us/step - loss: 0.7506 - val_loss: 1.0163
# Epoch 266/700
# 93/93 [==============================] - 0s 151us/step - loss: 0.7485 - val_loss: 1.0172
# Epoch 267/700
# 93/93 [==============================] - 0s 183us/step - loss: 0.7476 - val_loss: 1.0177
# Epoch 268/700
# 93/93 [==============================] - 0s 184us/step - loss: 0.7480 - val_loss: 1.0175
# Epoch 269/700
# 93/93 [==============================] - 0s 178us/step - loss: 0.7476 - val_loss: 1.0175
# Epoch 270/700
# 93/93 [==============================] - 0s 143us/step - loss: 0.7461 - val_loss: 1.0175
# Epoch 271/700
# 93/93 [==============================] - 0s 148us/step - loss: 0.7469 - val_loss: 1.0180
# Epoch 272/700
# 93/93 [==============================] - 0s 171us/step - loss: 0.7437 - val_loss: 1.0186
# Epoch 273/700
# 93/93 [==============================] - 0s 183us/step - loss: 0.7444 - val_loss: 1.0186
# Epoch 274/700
# 93/93 [==============================] - 0s 234us/step - loss: 0.7421 - val_loss: 1.0192
# Epoch 275/700
# 93/93 [==============================] - 0s 218us/step - loss: 0.7426 - val_loss: 1.0196
# Epoch 276/700
# 93/93 [==============================] - 0s 161us/step - loss: 0.7407 - val_loss: 1.0197
# Epoch 277/700
# 93/93 [==============================] - 0s 178us/step - loss: 0.7400 - val_loss: 1.0211
# Epoch 278/700
# 93/93 [==============================] - 0s 153us/step - loss: 0.7397 - val_loss: 1.0219
# Epoch 279/700
# 93/93 [==============================] - 0s 179us/step - loss: 0.7389 - val_loss: 1.0218
# Epoch 280/700
# 93/93 [==============================] - 0s 192us/step - loss: 0.7382 - val_loss: 1.0226
# Epoch 281/700
# 93/93 [==============================] - 0s 179us/step - loss: 0.7373 - val_loss: 1.0237
# Epoch 282/700
# 93/93 [==============================] - 0s 167us/step - loss: 0.7368 - val_loss: 1.0243
# Epoch 283/700
# 93/93 [==============================] - 0s 163us/step - loss: 0.7348 - val_loss: 1.0248
# Epoch 284/700
# 93/93 [==============================] - 0s 205us/step - loss: 0.7349 - val_loss: 1.0246
# Epoch 285/700
# 93/93 [==============================] - 0s 185us/step - loss: 0.7339 - val_loss: 1.0257
# Epoch 286/700
# 93/93 [==============================] - 0s 153us/step - loss: 0.7328 - val_loss: 1.0270
# Epoch 287/700
# 93/93 [==============================] - 0s 194us/step - loss: 0.7322 - val_loss: 1.0276
# Epoch 288/700
# 93/93 [==============================] - 0s 156us/step - loss: 0.7319 - val_loss: 1.0276
# Epoch 289/700
# 93/93 [==============================] - 0s 191us/step - loss: 0.7309 - val_loss: 1.0281
# Epoch 290/700
# 93/93 [==============================] - 0s 162us/step - loss: 0.7297 - val_loss: 1.0288
# Epoch 291/700
# 93/93 [==============================] - 0s 196us/step - loss: 0.7303 - val_loss: 1.0294
# Epoch 292/700
# 93/93 [==============================] - 0s 185us/step - loss: 0.7286 - val_loss: 1.0294
# Epoch 293/700
# 93/93 [==============================] - 0s 158us/step - loss: 0.7281 - val_loss: 1.0300
# Epoch 294/700
# 93/93 [==============================] - 0s 165us/step - loss: 0.7266 - val_loss: 1.0315
# Epoch 295/700
# 93/93 [==============================] - 0s 157us/step - loss: 0.7266 - val_loss: 1.0318
# Epoch 296/700
# 93/93 [==============================] - 0s 200us/step - loss: 0.7254 - val_loss: 1.0324
# Epoch 297/700
# 93/93 [==============================] - 0s 182us/step - loss: 0.7249 - val_loss: 1.0335
# Epoch 298/700
# 93/93 [==============================] - 0s 192us/step - loss: 0.7246 - val_loss: 1.0335
# Epoch 299/700
# 93/93 [==============================] - 0s 175us/step - loss: 0.7237 - val_loss: 1.0348
# Epoch 300/700
# 93/93 [==============================] - 0s 156us/step - loss: 0.7224 - val_loss: 1.0360
# Epoch 301/700
# 93/93 [==============================] - 0s 166us/step - loss: 0.7218 - val_loss: 1.0367
# Epoch 302/700
# 93/93 [==============================] - 0s 177us/step - loss: 0.7214 - val_loss: 1.0378
# Epoch 303/700
# 93/93 [==============================] - 0s 166us/step - loss: 0.7201 - val_loss: 1.0386
# Epoch 304/700
# 93/93 [==============================] - 0s 148us/step - loss: 0.7197 - val_loss: 1.0392
# Epoch 305/700
# 93/93 [==============================] - 0s 135us/step - loss: 0.7201 - val_loss: 1.0405
# Epoch 306/700
# 93/93 [==============================] - 0s 157us/step - loss: 0.7186 - val_loss: 1.0413
# Epoch 307/700
# 93/93 [==============================] - 0s 154us/step - loss: 0.7175 - val_loss: 1.0413
# Epoch 308/700
# 93/93 [==============================] - 0s 165us/step - loss: 0.7178 - val_loss: 1.0419
# Epoch 309/700
# 93/93 [==============================] - 0s 189us/step - loss: 0.7164 - val_loss: 1.0426
# Epoch 310/700
# 93/93 [==============================] - 0s 234us/step - loss: 0.7152 - val_loss: 1.0438
# Epoch 311/700
# 93/93 [==============================] - 0s 184us/step - loss: 0.7144 - val_loss: 1.0441
# Epoch 312/700
# 93/93 [==============================] - 0s 172us/step - loss: 0.7138 - val_loss: 1.0448
# Epoch 313/700
# 93/93 [==============================] - 0s 217us/step - loss: 0.7141 - val_loss: 1.0459
# Epoch 314/700
# 93/93 [==============================] - 0s 189us/step - loss: 0.7120 - val_loss: 1.0468
# Epoch 315/700
# 93/93 [==============================] - 0s 164us/step - loss: 0.7130 - val_loss: 1.0466
# Epoch 316/700
# 93/93 [==============================] - 0s 147us/step - loss: 0.7127 - val_loss: 1.0477
# Epoch 317/700
# 93/93 [==============================] - 0s 150us/step - loss: 0.7112 - val_loss: 1.0490
# Epoch 318/700
# 93/93 [==============================] - 0s 211us/step - loss: 0.7110 - val_loss: 1.0491
# Epoch 319/700
# 93/93 [==============================] - 0s 171us/step - loss: 0.7108 - val_loss: 1.0494
# Epoch 320/700
# 93/93 [==============================] - 0s 173us/step - loss: 0.7088 - val_loss: 1.0505
# Epoch 321/700
# 93/93 [==============================] - 0s 143us/step - loss: 0.7072 - val_loss: 1.0515
# Epoch 322/700
# 93/93 [==============================] - 0s 138us/step - loss: 0.7080 - val_loss: 1.0522
# Epoch 323/700
# 93/93 [==============================] - 0s 137us/step - loss: 0.7068 - val_loss: 1.0525
# Epoch 324/700
# 93/93 [==============================] - 0s 164us/step - loss: 0.7057 - val_loss: 1.0533
# Epoch 325/700
# 93/93 [==============================] - 0s 176us/step - loss: 0.7054 - val_loss: 1.0539
# Epoch 326/700
# 93/93 [==============================] - 0s 171us/step - loss: 0.7041 - val_loss: 1.0548
# Epoch 327/700
# 93/93 [==============================] - 0s 147us/step - loss: 0.7043 - val_loss: 1.0555
# Epoch 328/700
# 93/93 [==============================] - 0s 147us/step - loss: 0.7041 - val_loss: 1.0559
# Epoch 329/700
# 93/93 [==============================] - 0s 165us/step - loss: 0.7023 - val_loss: 1.0564
# Epoch 330/700
# 93/93 [==============================] - 0s 210us/step - loss: 0.7018 - val_loss: 1.0574
# Epoch 331/700
# 93/93 [==============================] - 0s 185us/step - loss: 0.7005 - val_loss: 1.0579
# Epoch 332/700
# 93/93 [==============================] - 0s 179us/step - loss: 0.7010 - val_loss: 1.0584
# Epoch 333/700
# 93/93 [==============================] - 0s 180us/step - loss: 0.7008 - val_loss: 1.0600
# Epoch 334/700
# 93/93 [==============================] - 0s 209us/step - loss: 0.6991 - val_loss: 1.0599
# Epoch 335/700
# 93/93 [==============================] - 0s 194us/step - loss: 0.6982 - val_loss: 1.0604
# Epoch 336/700
# 93/93 [==============================] - 0s 202us/step - loss: 0.6978 - val_loss: 1.0612
# Epoch 337/700
# 93/93 [==============================] - 0s 175us/step - loss: 0.6970 - val_loss: 1.0615
# Epoch 338/700
# 93/93 [==============================] - 0s 172us/step - loss: 0.6966 - val_loss: 1.0627
# Epoch 339/700
# 93/93 [==============================] - 0s 148us/step - loss: 0.6966 - val_loss: 1.0647
# Epoch 340/700
# 93/93 [==============================] - 0s 144us/step - loss: 0.6961 - val_loss: 1.0643
# Epoch 341/700
# 93/93 [==============================] - 0s 123us/step - loss: 0.6950 - val_loss: 1.0648
# Epoch 342/700
# 93/93 [==============================] - 0s 198us/step - loss: 0.6947 - val_loss: 1.0664
# Epoch 343/700
# 93/93 [==============================] - 0s 228us/step - loss: 0.6932 - val_loss: 1.0673
# Epoch 344/700
# 93/93 [==============================] - 0s 163us/step - loss: 0.6924 - val_loss: 1.0681
# Epoch 345/700
# 93/93 [==============================] - 0s 151us/step - loss: 0.6924 - val_loss: 1.0693
# Epoch 346/700
# 93/93 [==============================] - 0s 158us/step - loss: 0.6914 - val_loss: 1.0702
# Epoch 347/700
# 93/93 [==============================] - 0s 128us/step - loss: 0.6916 - val_loss: 1.0699
# Epoch 348/700
# 93/93 [==============================] - 0s 132us/step - loss: 0.6918 - val_loss: 1.0708
# Epoch 349/700
# 93/93 [==============================] - 0s 164us/step - loss: 0.6902 - val_loss: 1.0708
# Epoch 350/700
# 93/93 [==============================] - 0s 164us/step - loss: 0.6886 - val_loss: 1.0714
# Epoch 351/700
# 93/93 [==============================] - 0s 201us/step - loss: 0.6884 - val_loss: 1.0723
# Epoch 352/700
# 93/93 [==============================] - 0s 167us/step - loss: 0.6895 - val_loss: 1.0732
# Epoch 353/700
# 93/93 [==============================] - 0s 230us/step - loss: 0.6876 - val_loss: 1.0746
# Epoch 354/700
# 93/93 [==============================] - 0s 189us/step - loss: 0.6864 - val_loss: 1.0756
# Epoch 355/700
# 93/93 [==============================] - 0s 146us/step - loss: 0.6865 - val_loss: 1.0769
# Epoch 356/700
# 93/93 [==============================] - 0s 129us/step - loss: 0.6850 - val_loss: 1.0778
# Epoch 357/700
# 93/93 [==============================] - 0s 133us/step - loss: 0.6857 - val_loss: 1.0786
# Epoch 358/700
# 93/93 [==============================] - 0s 170us/step - loss: 0.6845 - val_loss: 1.0796
# Epoch 359/700
# 93/93 [==============================] - 0s 129us/step - loss: 0.6848 - val_loss: 1.0803
# Epoch 360/700
# 93/93 [==============================] - 0s 122us/step - loss: 0.6836 - val_loss: 1.0804
# Epoch 361/700
# 93/93 [==============================] - 0s 138us/step - loss: 0.6827 - val_loss: 1.0822
# Epoch 362/700
# 93/93 [==============================] - 0s 145us/step - loss: 0.6828 - val_loss: 1.0830
# Epoch 363/700
# 93/93 [==============================] - 0s 160us/step - loss: 0.6819 - val_loss: 1.0839
# Epoch 364/700
# 93/93 [==============================] - 0s 122us/step - loss: 0.6814 - val_loss: 1.0849
# Epoch 365/700
# 93/93 [==============================] - 0s 159us/step - loss: 0.6812 - val_loss: 1.0848
# Epoch 366/700
# 93/93 [==============================] - 0s 154us/step - loss: 0.6797 - val_loss: 1.0858
# Epoch 367/700
# 93/93 [==============================] - 0s 140us/step - loss: 0.6792 - val_loss: 1.0862
# Epoch 368/700
# 93/93 [==============================] - 0s 141us/step - loss: 0.6788 - val_loss: 1.0871
# Epoch 369/700
# 93/93 [==============================] - 0s 145us/step - loss: 0.6798 - val_loss: 1.0878
# Epoch 370/700
# 93/93 [==============================] - 0s 143us/step - loss: 0.6780 - val_loss: 1.0889
# Epoch 371/700
# 93/93 [==============================] - 0s 146us/step - loss: 0.6764 - val_loss: 1.0888
# Epoch 372/700
# 93/93 [==============================] - 0s 141us/step - loss: 0.6774 - val_loss: 1.0900
# Epoch 373/700
# 93/93 [==============================] - 0s 131us/step - loss: 0.6757 - val_loss: 1.0902
# Epoch 374/700
# 93/93 [==============================] - 0s 133us/step - loss: 0.6766 - val_loss: 1.0920
# Epoch 375/700
# 93/93 [==============================] - 0s 150us/step - loss: 0.6754 - val_loss: 1.0930
# Epoch 376/700
# 93/93 [==============================] - 0s 152us/step - loss: 0.6750 - val_loss: 1.0939
# Epoch 377/700
# 93/93 [==============================] - 0s 130us/step - loss: 0.6738 - val_loss: 1.0937
# Epoch 378/700
# 93/93 [==============================] - 0s 154us/step - loss: 0.6740 - val_loss: 1.0940
# Epoch 379/700
# 93/93 [==============================] - 0s 207us/step - loss: 0.6724 - val_loss: 1.0951
# Epoch 380/700
# 93/93 [==============================] - 0s 145us/step - loss: 0.6719 - val_loss: 1.0962
# Epoch 381/700
# 93/93 [==============================] - 0s 149us/step - loss: 0.6713 - val_loss: 1.0969
# Epoch 382/700
# 93/93 [==============================] - 0s 193us/step - loss: 0.6711 - val_loss: 1.0978
# Epoch 383/700
# 93/93 [==============================] - 0s 149us/step - loss: 0.6717 - val_loss: 1.0976
# Epoch 384/700
# 93/93 [==============================] - 0s 163us/step - loss: 0.6709 - val_loss: 1.0984
# Epoch 385/700
# 93/93 [==============================] - 0s 156us/step - loss: 0.6688 - val_loss: 1.0990
# Epoch 386/700
# 93/93 [==============================] - 0s 131us/step - loss: 0.6684 - val_loss: 1.1002
# Epoch 387/700
# 93/93 [==============================] - 0s 201us/step - loss: 0.6679 - val_loss: 1.1007
# Epoch 388/700
# 93/93 [==============================] - 0s 121us/step - loss: 0.6691 - val_loss: 1.1020
# Epoch 389/700
# 93/93 [==============================] - 0s 142us/step - loss: 0.6673 - val_loss: 1.1028
# Epoch 390/700
# 93/93 [==============================] - 0s 145us/step - loss: 0.6668 - val_loss: 1.1036
# Epoch 391/700
# 93/93 [==============================] - 0s 181us/step - loss: 0.6669 - val_loss: 1.1037
# Epoch 392/700
# 93/93 [==============================] - 0s 170us/step - loss: 0.6666 - val_loss: 1.1063
# Epoch 393/700
# 93/93 [==============================] - 0s 232us/step - loss: 0.6648 - val_loss: 1.1070
# Epoch 394/700
# 93/93 [==============================] - 0s 214us/step - loss: 0.6666 - val_loss: 1.1082
# Epoch 395/700
# 93/93 [==============================] - 0s 187us/step - loss: 0.6651 - val_loss: 1.1084
# Epoch 396/700
# 93/93 [==============================] - 0s 148us/step - loss: 0.6646 - val_loss: 1.1094
# Epoch 397/700
# 93/93 [==============================] - 0s 148us/step - loss: 0.6632 - val_loss: 1.1108
# Epoch 398/700
# 93/93 [==============================] - 0s 162us/step - loss: 0.6630 - val_loss: 1.1114
# Epoch 399/700
# 93/93 [==============================] - 0s 178us/step - loss: 0.6621 - val_loss: 1.1121
# Epoch 400/700
# 93/93 [==============================] - 0s 155us/step - loss: 0.6610 - val_loss: 1.1129
# Epoch 401/700
# 93/93 [==============================] - 0s 166us/step - loss: 0.6627 - val_loss: 1.1136
# Epoch 402/700
# 93/93 [==============================] - 0s 157us/step - loss: 0.6620 - val_loss: 1.1144
# Epoch 403/700
# 93/93 [==============================] - 0s 178us/step - loss: 0.6594 - val_loss: 1.1160
# Epoch 404/700
# 93/93 [==============================] - 0s 167us/step - loss: 0.6608 - val_loss: 1.1160
# Epoch 405/700
# 93/93 [==============================] - 0s 158us/step - loss: 0.6592 - val_loss: 1.1172
# Epoch 406/700
# 93/93 [==============================] - 0s 141us/step - loss: 0.6583 - val_loss: 1.1187
# Epoch 407/700
# 93/93 [==============================] - 0s 200us/step - loss: 0.6579 - val_loss: 1.1199
# Epoch 408/700
# 93/93 [==============================] - 0s 170us/step - loss: 0.6569 - val_loss: 1.1207
# Epoch 409/700
# 93/93 [==============================] - 0s 156us/step - loss: 0.6571 - val_loss: 1.1228
# Epoch 410/700
# 93/93 [==============================] - 0s 145us/step - loss: 0.6557 - val_loss: 1.1227
# Epoch 411/700
# 93/93 [==============================] - 0s 143us/step - loss: 0.6572 - val_loss: 1.1241
# Epoch 412/700
# 93/93 [==============================] - 0s 126us/step - loss: 0.6580 - val_loss: 1.1243
# Epoch 413/700
# 93/93 [==============================] - 0s 138us/step - loss: 0.6553 - val_loss: 1.1253
# Epoch 414/700
# 93/93 [==============================] - 0s 141us/step - loss: 0.6538 - val_loss: 1.1267
# Epoch 415/700
# 93/93 [==============================] - 0s 182us/step - loss: 0.6540 - val_loss: 1.1263
# Epoch 416/700
# 93/93 [==============================] - 0s 143us/step - loss: 0.6553 - val_loss: 1.1261
# Epoch 417/700
# 93/93 [==============================] - 0s 162us/step - loss: 0.6536 - val_loss: 1.1266
# Epoch 418/700
# 93/93 [==============================] - 0s 177us/step - loss: 0.6532 - val_loss: 1.1282
# Epoch 419/700
# 93/93 [==============================] - 0s 198us/step - loss: 0.6513 - val_loss: 1.1289
# Epoch 420/700
# 93/93 [==============================] - 0s 158us/step - loss: 0.6511 - val_loss: 1.1307
# Epoch 421/700
# 93/93 [==============================] - 0s 172us/step - loss: 0.6521 - val_loss: 1.1310
# Epoch 422/700
# 93/93 [==============================] - 0s 151us/step - loss: 0.6501 - val_loss: 1.1324
# Epoch 423/700
# 93/93 [==============================] - 0s 133us/step - loss: 0.6506 - val_loss: 1.1336
# Epoch 424/700
# 93/93 [==============================] - 0s 158us/step - loss: 0.6505 - val_loss: 1.1344
# Epoch 425/700
# 93/93 [==============================] - 0s 152us/step - loss: 0.6482 - val_loss: 1.1350
# Epoch 426/700
# 93/93 [==============================] - 0s 155us/step - loss: 0.6480 - val_loss: 1.1365
# Epoch 427/700
# 93/93 [==============================] - 0s 161us/step - loss: 0.6497 - val_loss: 1.1372
# Epoch 428/700
# 93/93 [==============================] - 0s 140us/step - loss: 0.6470 - val_loss: 1.1379
# Epoch 429/700
# 93/93 [==============================] - 0s 141us/step - loss: 0.6475 - val_loss: 1.1393
# Epoch 430/700
# 93/93 [==============================] - 0s 173us/step - loss: 0.6483 - val_loss: 1.1399
# Epoch 431/700
# 93/93 [==============================] - 0s 144us/step - loss: 0.6461 - val_loss: 1.1400
# Epoch 432/700
# 93/93 [==============================] - 0s 196us/step - loss: 0.6459 - val_loss: 1.1410
# Epoch 433/700
# 93/93 [==============================] - 0s 145us/step - loss: 0.6460 - val_loss: 1.1427
# Epoch 434/700
# 93/93 [==============================] - 0s 140us/step - loss: 0.6449 - val_loss: 1.1444
# Epoch 435/700
# 93/93 [==============================] - 0s 122us/step - loss: 0.6453 - val_loss: 1.1434
# Epoch 436/700
# 93/93 [==============================] - 0s 122us/step - loss: 0.6439 - val_loss: 1.1450
# Epoch 437/700
# 93/93 [==============================] - 0s 170us/step - loss: 0.6432 - val_loss: 1.1461
# Epoch 438/700
# 93/93 [==============================] - 0s 139us/step - loss: 0.6455 - val_loss: 1.1476
# Epoch 439/700
# 93/93 [==============================] - 0s 227us/step - loss: 0.6430 - val_loss: 1.1477
# Epoch 440/700
# 93/93 [==============================] - 0s 162us/step - loss: 0.6425 - val_loss: 1.1485
# Epoch 441/700
# 93/93 [==============================] - 0s 175us/step - loss: 0.6411 - val_loss: 1.1491
# Epoch 442/700
# 93/93 [==============================] - 0s 177us/step - loss: 0.6406 - val_loss: 1.1503
# Epoch 443/700
# 93/93 [==============================] - 0s 168us/step - loss: 0.6418 - val_loss: 1.1512
# Epoch 444/700
# 93/93 [==============================] - 0s 183us/step - loss: 0.6401 - val_loss: 1.1498
# Epoch 445/700
# 93/93 [==============================] - 0s 195us/step - loss: 0.6406 - val_loss: 1.1515
# Epoch 446/700
# 93/93 [==============================] - 0s 202us/step - loss: 0.6390 - val_loss: 1.1530
# Epoch 447/700
# 93/93 [==============================] - 0s 193us/step - loss: 0.6388 - val_loss: 1.1533
# Epoch 448/700
# 93/93 [==============================] - 0s 174us/step - loss: 0.6379 - val_loss: 1.1539
# Epoch 449/700
# 93/93 [==============================] - 0s 150us/step - loss: 0.6375 - val_loss: 1.1553
# Epoch 450/700
# 93/93 [==============================] - 0s 143us/step - loss: 0.6383 - val_loss: 1.1560
# Epoch 451/700
# 93/93 [==============================] - 0s 163us/step - loss: 0.6378 - val_loss: 1.1557
# Epoch 452/700
# 93/93 [==============================] - 0s 152us/step - loss: 0.6366 - val_loss: 1.1578
# Epoch 453/700
# 93/93 [==============================] - 0s 130us/step - loss: 0.6372 - val_loss: 1.1573
# Epoch 454/700
# 93/93 [==============================] - 0s 136us/step - loss: 0.6354 - val_loss: 1.1577
# Epoch 455/700
# 93/93 [==============================] - 0s 183us/step - loss: 0.6366 - val_loss: 1.1579
# Epoch 456/700
# 93/93 [==============================] - 0s 153us/step - loss: 0.6344 - val_loss: 1.1580
# Epoch 457/700
# 93/93 [==============================] - 0s 174us/step - loss: 0.6341 - val_loss: 1.1593
# Epoch 458/700
# 93/93 [==============================] - 0s 163us/step - loss: 0.6354 - val_loss: 1.1597
# Epoch 459/700
# 93/93 [==============================] - 0s 129us/step - loss: 0.6339 - val_loss: 1.1614
# Epoch 460/700
# 93/93 [==============================] - 0s 141us/step - loss: 0.6332 - val_loss: 1.1623
# Epoch 461/700
# 93/93 [==============================] - 0s 148us/step - loss: 0.6331 - val_loss: 1.1645
# Epoch 462/700
# 93/93 [==============================] - 0s 124us/step - loss: 0.6337 - val_loss: 1.1655
# Epoch 463/700
# 93/93 [==============================] - 0s 122us/step - loss: 0.6329 - val_loss: 1.1654
# Epoch 464/700
# 93/93 [==============================] - 0s 181us/step - loss: 0.6308 - val_loss: 1.1655
# Epoch 465/700
# 93/93 [==============================] - 0s 169us/step - loss: 0.6311 - val_loss: 1.1666
# Epoch 466/700
# 93/93 [==============================] - 0s 169us/step - loss: 0.6307 - val_loss: 1.1671
# Epoch 467/700
# ...
# Epoch 546/700
# 93/93 [==============================] - 0s 149us/step - loss: 0.5977 - val_loss: 1.2424
# Epoch 547/700
# 93/93 [==============================] - 0s 189us/step - loss: 0.5988 - val_loss: 1.2429
# Epoch 548/700
# 93/93 [==============================] - 0s 175us/step - loss: 0.5980 - val_loss: 1.2439
# Epoch 549/700
# 93/93 [==============================] - 0s 159us/step - loss: 0.5965 - val_loss: 1.2458
# Epoch 550/700
# 93/93 [==============================] - 0s 170us/step - loss: 0.5969 - val_loss: 1.2477
# Epoch 551/700
# 93/93 [==============================] - 0s 185us/step - loss: 0.5956 - val_loss: 1.2464
# Epoch 552/700
# 93/93 [==============================] - 0s 168us/step - loss: 0.5938 - val_loss: 1.2473
# Epoch 553/700
# 93/93 [==============================] - 0s 174us/step - loss: 0.5946 - val_loss: 1.2488
# Epoch 554/700
# 93/93 [==============================] - 0s 187us/step - loss: 0.5947 - val_loss: 1.2502
# Epoch 555/700
# 93/93 [==============================] - 0s 163us/step - loss: 0.5952 - val_loss: 1.2493
# Epoch 556/700
# 93/93 [==============================] - 0s 157us/step - loss: 0.5932 - val_loss: 1.2502
# Epoch 557/700
# 93/93 [==============================] - 0s 186us/step - loss: 0.5928 - val_loss: 1.2519
# Epoch 558/700
# 93/93 [==============================] - 0s 156us/step - loss: 0.5930 - val_loss: 1.2524
# Epoch 559/700
# 93/93 [==============================] - 0s 207us/step - loss: 0.5929 - val_loss: 1.2515
# Epoch 560/700
# 93/93 [==============================] - 0s 171us/step - loss: 0.5912 - val_loss: 1.2514
# Epoch 561/700
# 93/93 [==============================] - 0s 165us/step - loss: 0.5908 - val_loss: 1.2532
# Epoch 562/700
# 93/93 [==============================] - 0s 167us/step - loss: 0.5917 - val_loss: 1.2551
# Epoch 563/700
# 93/93 [==============================] - 0s 183us/step - loss: 0.5912 - val_loss: 1.2548
# Epoch 564/700
# 93/93 [==============================] - 0s 194us/step - loss: 0.5911 - val_loss: 1.2563
# Epoch 565/700
# 93/93 [==============================] - 0s 161us/step - loss: 0.5908 - val_loss: 1.2574
# Epoch 566/700
# 93/93 [==============================] - 0s 130us/step - loss: 0.5908 - val_loss: 1.2586
# Epoch 567/700
# 93/93 [==============================] - 0s 171us/step - loss: 0.5891 - val_loss: 1.2587
# Epoch 568/700
# 93/93 [==============================] - 0s 177us/step - loss: 0.5884 - val_loss: 1.2591
# Epoch 569/700
# 93/93 [==============================] - 0s 186us/step - loss: 0.5876 - val_loss: 1.2589
# Epoch 570/700
# 93/93 [==============================] - 0s 193us/step - loss: 0.5880 - val_loss: 1.2607
# Epoch 571/700
# 93/93 [==============================] - 0s 129us/step - loss: 0.5881 - val_loss: 1.2637
# Epoch 572/700
# 93/93 [==============================] - 0s 163us/step - loss: 0.5860 - val_loss: 1.2646
# Epoch 573/700
# 93/93 [==============================] - 0s 138us/step - loss: 0.5869 - val_loss: 1.2655
# Epoch 574/700
# 93/93 [==============================] - 0s 140us/step - loss: 0.5862 - val_loss: 1.2660
# Epoch 575/700
# 93/93 [==============================] - 0s 152us/step - loss: 0.5867 - val_loss: 1.2670
# Epoch 576/700
# 93/93 [==============================] - 0s 143us/step - loss: 0.5855 - val_loss: 1.2675
# Epoch 577/700
# 93/93 [==============================] - 0s 141us/step - loss: 0.5850 - val_loss: 1.2678
# Epoch 578/700
# 93/93 [==============================] - 0s 139us/step - loss: 0.5862 - val_loss: 1.2705
# Epoch 579/700
# 93/93 [==============================] - 0s 175us/step - loss: 0.5857 - val_loss: 1.2704
# Epoch 580/700
# 93/93 [==============================] - 0s 179us/step - loss: 0.5839 - val_loss: 1.2708
# Epoch 581/700
# 93/93 [==============================] - 0s 167us/step - loss: 0.5853 - val_loss: 1.2720
# Epoch 582/700
# 93/93 [==============================] - 0s 173us/step - loss: 0.5852 - val_loss: 1.2713
# Epoch 583/700
# 93/93 [==============================] - 0s 227us/step - loss: 0.5829 - val_loss: 1.2724
# Epoch 584/700
# 93/93 [==============================] - 0s 168us/step - loss: 0.5825 - val_loss: 1.2728
# Epoch 585/700
# 93/93 [==============================] - 0s 151us/step - loss: 0.5816 - val_loss: 1.2749
# Epoch 586/700
# 93/93 [==============================] - 0s 171us/step - loss: 0.5819 - val_loss: 1.2756
# Epoch 587/700
# 93/93 [==============================] - 0s 178us/step - loss: 0.5817 - val_loss: 1.2767
# Epoch 588/700
# 93/93 [==============================] - 0s 182us/step - loss: 0.5807 - val_loss: 1.2764
# Epoch 589/700
# 93/93 [==============================] - 0s 188us/step - loss: 0.5817 - val_loss: 1.2763
# Epoch 590/700
# 93/93 [==============================] - 0s 171us/step - loss: 0.5803 - val_loss: 1.2787
# Epoch 591/700
# 93/93 [==============================] - 0s 165us/step - loss: 0.5831 - val_loss: 1.2797
# Epoch 592/700
# 93/93 [==============================] - 0s 165us/step - loss: 0.5793 - val_loss: 1.2815
# Epoch 593/700
# 93/93 [==============================] - 0s 154us/step - loss: 0.5797 - val_loss: 1.2816
# Epoch 594/700
# 93/93 [==============================] - 0s 183us/step - loss: 0.5810 - val_loss: 1.2834
# Epoch 595/700
# 93/93 [==============================] - 0s 153us/step - loss: 0.5796 - val_loss: 1.2855
# Epoch 596/700
# 93/93 [==============================] - 0s 147us/step - loss: 0.5796 - val_loss: 1.2851
# Epoch 597/700
# 93/93 [==============================] - 0s 142us/step - loss: 0.5784 - val_loss: 1.2873
# Epoch 598/700
# 93/93 [==============================] - 0s 183us/step - loss: 0.5792 - val_loss: 1.2853
# Epoch 599/700
# 93/93 [==============================] - 0s 177us/step - loss: 0.5780 - val_loss: 1.2852
# Epoch 600/700
# 93/93 [==============================] - 0s 157us/step - loss: 0.5771 - val_loss: 1.2850
# Epoch 601/700
# 93/93 [==============================] - 0s 154us/step - loss: 0.5771 - val_loss: 1.2876
# Epoch 602/700
# 93/93 [==============================] - 0s 134us/step - loss: 0.5789 - val_loss: 1.2894
# Epoch 603/700
# 93/93 [==============================] - 0s 186us/step - loss: 0.5764 - val_loss: 1.2891
# Epoch 604/700
# 93/93 [==============================] - 0s 147us/step - loss: 0.5764 - val_loss: 1.2880
# Epoch 605/700
# 93/93 [==============================] - 0s 161us/step - loss: 0.5773 - val_loss: 1.2935
# Epoch 606/700
# 93/93 [==============================] - 0s 159us/step - loss: 0.5748 - val_loss: 1.2926
# Epoch 607/700
# 93/93 [==============================] - 0s 159us/step - loss: 0.5742 - val_loss: 1.2922
# Epoch 608/700
# 93/93 [==============================] - 0s 142us/step - loss: 0.5739 - val_loss: 1.2938
# Epoch 609/700
# 93/93 [==============================] - 0s 135us/step - loss: 0.5739 - val_loss: 1.2948
# Epoch 610/700
# 93/93 [==============================] - 0s 149us/step - loss: 0.5746 - val_loss: 1.2928
# Epoch 611/700
# 93/93 [==============================] - 0s 160us/step - loss: 0.5743 - val_loss: 1.2938
# Epoch 612/700
# 93/93 [==============================] - 0s 153us/step - loss: 0.5726 - val_loss: 1.2940
# Epoch 613/700
# 93/93 [==============================] - 0s 149us/step - loss: 0.5728 - val_loss: 1.2954
# Epoch 614/700
# 93/93 [==============================] - 0s 151us/step - loss: 0.5716 - val_loss: 1.2974
# Epoch 615/700
# 93/93 [==============================] - 0s 143us/step - loss: 0.5708 - val_loss: 1.2979
# Epoch 616/700
# 93/93 [==============================] - 0s 158us/step - loss: 0.5724 - val_loss: 1.2985
# Epoch 617/700
# 93/93 [==============================] - 0s 159us/step - loss: 0.5721 - val_loss: 1.3012
# Epoch 618/700
# 93/93 [==============================] - 0s 150us/step - loss: 0.5704 - val_loss: 1.3021
# Epoch 619/700
# 93/93 [==============================] - 0s 149us/step - loss: 0.5704 - val_loss: 1.3050
# Epoch 620/700
# 93/93 [==============================] - 0s 154us/step - loss: 0.5701 - val_loss: 1.3046
# Epoch 621/700
# 93/93 [==============================] - 0s 131us/step - loss: 0.5689 - val_loss: 1.3057
# Epoch 622/700
# 93/93 [==============================] - 0s 123us/step - loss: 0.5684 - val_loss: 1.3063
# Epoch 623/700
# 93/93 [==============================] - 0s 165us/step - loss: 0.5698 - val_loss: 1.3071
# Epoch 624/700
# 93/93 [==============================] - 0s 146us/step - loss: 0.5681 - val_loss: 1.3083
# Epoch 625/700
# 93/93 [==============================] - 0s 141us/step - loss: 0.5696 - val_loss: 1.3083
# Epoch 626/700
# 93/93 [==============================] - 0s 132us/step - loss: 0.5690 - val_loss: 1.3090
# Epoch 627/700
# 93/93 [==============================] - 0s 160us/step - loss: 0.5665 - val_loss: 1.3091
# Epoch 628/700
# 93/93 [==============================] - 0s 156us/step - loss: 0.5668 - val_loss: 1.3109
# Epoch 629/700
# 93/93 [==============================] - 0s 145us/step - loss: 0.5669 - val_loss: 1.3095
# Epoch 630/700
# 93/93 [==============================] - 0s 124us/step - loss: 0.5655 - val_loss: 1.3093
# Epoch 631/700
# 93/93 [==============================] - 0s 167us/step - loss: 0.5657 - val_loss: 1.3107
# Epoch 632/700
# 93/93 [==============================] - 0s 151us/step - loss: 0.5662 - val_loss: 1.3111
# Epoch 633/700
# 93/93 [==============================] - 0s 172us/step - loss: 0.5658 - val_loss: 1.3108
# Epoch 634/700
# 93/93 [==============================] - 0s 139us/step - loss: 0.5656 - val_loss: 1.3122
# Epoch 635/700
# 93/93 [==============================] - 0s 138us/step - loss: 0.5653 - val_loss: 1.3108
# Epoch 636/700
# 93/93 [==============================] - 0s 125us/step - loss: 0.5666 - val_loss: 1.3120
# Epoch 637/700
# 93/93 [==============================] - 0s 123us/step - loss: 0.5630 - val_loss: 1.3121
# Epoch 638/700
# 93/93 [==============================] - 0s 140us/step - loss: 0.5644 - val_loss: 1.3147
# Epoch 639/700
# 93/93 [==============================] - 0s 147us/step - loss: 0.5628 - val_loss: 1.3155
# Epoch 640/700
# 93/93 [==============================] - 0s 191us/step - loss: 0.5627 - val_loss: 1.3168
# Epoch 641/700
# 93/93 [==============================] - 0s 136us/step - loss: 0.5633 - val_loss: 1.3178
# Epoch 642/700
# 93/93 [==============================] - 0s 149us/step - loss: 0.5624 - val_loss: 1.3179
# Epoch 643/700
# 93/93 [==============================] - 0s 174us/step - loss: 0.5612 - val_loss: 1.3178
# Epoch 644/700
# 93/93 [==============================] - 0s 151us/step - loss: 0.5623 - val_loss: 1.3193
# Epoch 645/700
# 93/93 [==============================] - 0s 152us/step - loss: 0.5610 - val_loss: 1.3193
# Epoch 646/700
# 93/93 [==============================] - 0s 144us/step - loss: 0.5613 - val_loss: 1.3205
# Epoch 647/700
# 93/93 [==============================] - 0s 142us/step - loss: 0.5599 - val_loss: 1.3210
# Epoch 648/700
# 93/93 [==============================] - 0s 146us/step - loss: 0.5596 - val_loss: 1.3225
# Epoch 649/700
# 93/93 [==============================] - 0s 204us/step - loss: 0.5586 - val_loss: 1.3239
# Epoch 650/700
# 93/93 [==============================] - 0s 184us/step - loss: 0.5588 - val_loss: 1.3252
# Epoch 651/700
# 93/93 [==============================] - 0s 176us/step - loss: 0.5573 - val_loss: 1.3262
# Epoch 652/700
# 93/93 [==============================] - 0s 181us/step - loss: 0.5581 - val_loss: 1.3270
# Epoch 653/700
# 93/93 [==============================] - 0s 170us/step - loss: 0.5570 - val_loss: 1.3273
# Epoch 654/700
# 93/93 [==============================] - 0s 188us/step - loss: 0.5563 - val_loss: 1.3271
# Epoch 655/700
# 93/93 [==============================] - 0s 158us/step - loss: 0.5566 - val_loss: 1.3291
# Epoch 656/700
# 93/93 [==============================] - 0s 152us/step - loss: 0.5590 - val_loss: 1.3287
# Epoch 657/700
# 93/93 [==============================] - 0s 142us/step - loss: 0.5571 - val_loss: 1.3290
# Epoch 658/700
# 93/93 [==============================] - 0s 150us/step - loss: 0.5572 - val_loss: 1.3298
# Epoch 659/700
# 93/93 [==============================] - 0s 142us/step - loss: 0.5551 - val_loss: 1.3299
# Epoch 660/700
# 93/93 [==============================] - 0s 140us/step - loss: 0.5581 - val_loss: 1.3284
# Epoch 661/700
# 93/93 [==============================] - 0s 161us/step - loss: 0.5550 - val_loss: 1.3297
# Epoch 662/700
# 93/93 [==============================] - 0s 149us/step - loss: 0.5563 - val_loss: 1.3299
# Epoch 663/700
# 93/93 [==============================] - 0s 194us/step - loss: 0.5533 - val_loss: 1.3324
# Epoch 664/700
# 93/93 [==============================] - 0s 224us/step - loss: 0.5534 - val_loss: 1.3331
# Epoch 665/700
# 93/93 [==============================] - 0s 160us/step - loss: 0.5536 - val_loss: 1.3351
# Epoch 666/700
# 93/93 [==============================] - 0s 249us/step - loss: 0.5525 - val_loss: 1.3363
# Epoch 667/700
# 93/93 [==============================] - 0s 242us/step - loss: 0.5548 - val_loss: 1.3344
# Epoch 668/700
# 93/93 [==============================] - 0s 141us/step - loss: 0.5532 - val_loss: 1.3338
# Epoch 669/700
# 93/93 [==============================] - 0s 165us/step - loss: 0.5522 - val_loss: 1.3355
# Epoch 670/700
# 93/93 [==============================] - 0s 156us/step - loss: 0.5521 - val_loss: 1.3376
# Epoch 671/700
# 93/93 [==============================] - 0s 151us/step - loss: 0.5511 - val_loss: 1.3379
# Epoch 672/700
# 93/93 [==============================] - 0s 154us/step - loss: 0.5522 - val_loss: 1.3381
# Epoch 673/700
# 93/93 [==============================] - 0s 171us/step - loss: 0.5508 - val_loss: 1.3401
# Epoch 674/700
# 93/93 [==============================] - 0s 166us/step - loss: 0.5498 - val_loss: 1.3406
# Epoch 675/700
# 93/93 [==============================] - 0s 203us/step - loss: 0.5496 - val_loss: 1.3433
# Epoch 676/700
# 93/93 [==============================] - 0s 161us/step - loss: 0.5494 - val_loss: 1.3453
# Epoch 677/700
# 93/93 [==============================] - 0s 174us/step - loss: 0.5512 - val_loss: 1.3449
# Epoch 678/700
# 93/93 [==============================] - 0s 203us/step - loss: 0.5481 - val_loss: 1.3468
# Epoch 679/700
# 93/93 [==============================] - 0s 169us/step - loss: 0.5488 - val_loss: 1.3479
# Epoch 680/700
# 93/93 [==============================] - 0s 158us/step - loss: 0.5486 - val_loss: 1.3487
# Epoch 681/700
# 93/93 [==============================] - 0s 172us/step - loss: 0.5484 - val_loss: 1.3485
# Epoch 682/700
# 93/93 [==============================] - 0s 150us/step - loss: 0.5481 - val_loss: 1.3507
# Epoch 683/700
# 93/93 [==============================] - 0s 179us/step - loss: 0.5464 - val_loss: 1.3499
# Epoch 684/700
# 93/93 [==============================] - 0s 175us/step - loss: 0.5462 - val_loss: 1.3517
# Epoch 685/700
# 93/93 [==============================] - 0s 174us/step - loss: 0.5450 - val_loss: 1.3524
# Epoch 686/700
# 93/93 [==============================] - 0s 184us/step - loss: 0.5491 - val_loss: 1.3536
# Epoch 687/700
# 93/93 [==============================] - 0s 215us/step - loss: 0.5442 - val_loss: 1.3552
# Epoch 688/700
# 93/93 [==============================] - 0s 156us/step - loss: 0.5466 - val_loss: 1.3561
# Epoch 689/700
# 93/93 [==============================] - 0s 139us/step - loss: 0.5448 - val_loss: 1.3560
# Epoch 690/700
# 93/93 [==============================] - 0s 161us/step - loss: 0.5443 - val_loss: 1.3575
# Epoch 691/700
# 93/93 [==============================] - 0s 181us/step - loss: 0.5439 - val_loss: 1.3584
# Epoch 692/700
# 93/93 [==============================] - 0s 186us/step - loss: 0.5432 - val_loss: 1.3573
# Epoch 693/700
# 93/93 [==============================] - 0s 174us/step - loss: 0.5448 - val_loss: 1.3587
# Epoch 694/700
# 93/93 [==============================] - 0s 162us/step - loss: 0.5437 - val_loss: 1.3598
# Epoch 695/700
# 93/93 [==============================] - 0s 125us/step - loss: 0.5416 - val_loss: 1.3598
# Epoch 696/700
# 93/93 [==============================] - 0s 155us/step - loss: 0.5424 - val_loss: 1.3609
# Epoch 697/700
# 93/93 [==============================] - 0s 162us/step - loss: 0.5438 - val_loss: 1.3597
# Epoch 698/700
# 93/93 [==============================] - 0s 173us/step - loss: 0.5428 - val_loss: 1.3591
# Epoch 699/700
# 93/93 [==============================] - 0s 158us/step - loss: 0.5418 - val_loss: 1.3586
# Epoch 700/700
# 93/93 [==============================] - 0s 140us/step - loss: 0.5401 - val_loss: 1.3611

# %%
# using predict_classes() for multi-class data to return predicted class index.

print(model.predict_classes(prediction_input_preprocessor.transform(X_test)))

prediction_index=model.predict_classes(prediction_input_preprocessor.transform(X_test))

#Now lets run some code to get keras to return the label rather than the index...

# get labels from one hot encoded y_train data
labels=pd.get_dummies(y_train).columns

# Function to use to return label from column index location
def index_to_label(labels,index_n): 
    return labels[index_n]
    
# Example: return label at predicted index location 1
index_to_label(labels,1)

# Iterate through all predicted indices using map method

predicted_labels=list(map(lambda x: labels[x], prediction_index))
print(predicted_labels)
# Out:
# [1 0 0 1 4 1 0 0 1 2 1 2 3 0 1 1 4 4 2 2 4 3 1 3 1 2 1 1 1 2 0 2 1 4 2 4 4
#  2 1]
# ['High', 'Average', 'Average', 'High', 'Very Low', 'High', 'Average', 'Average', 'High', 'Low', 'High', 'Low', 'Very High', 'Average', 'High', 'High', 'Very Low', 'Very Low', 'Low', 'Low', 'Very Low', 'Very High', 'High', 'Very High', 'High', 'Low', 'High', 'High', 'High', 'Low', 'Average', 'Low', 'High', 'Very Low', 'Low', 'Very Low', 'Very Low', 'Low', 'High']

# %%
modelevalobject=model_eval_metrics( y_test,predicted_labels,classification="TRUE")

modelevalobject
# Out:
#    accuracy  f1_score  precision    recall  mse  rmse  mae  r2
# 0  0.410256    0.4129   0.490476  0.433333    0     0    0   0

# %% [markdown]
# **Answer** I only knew how to to tune learning rate and epochs, and then messed around with the number of nodes and activation types. This is the best score I could get. Becuase the sample was very small, I made my layers in my model small. Because of the earlier feature extraction as well, I went out on a limb and guessed on a smaller hidden layer being superior, as some features, like region, were not that predictive. epochs represented the number of times the model goe through a data set and the learning rate adjusts how much is adjusts from previous epochs. Small layers, epochs, and learning rate were key in geting a decent score. I tried to do a convolutional neural net, but ran out of time

# %%
#installing onx to save model
! pip3 install keras2onnx
! pip3 install onnxruntime

# %%
#Convert keras model object to onnx and then save it to .onnx file
import os

if not os.path.exists('mymodel.onnx'):
    from keras2onnx import convert_keras
    onx = convert_keras(model, 'mymodel.onnx')
    with open("mymodel.onnx", "wb") as f:
        f.write(onx.SerializeToString())

# %%
#installing class aishare
! pip install https://github.com/mikedparrott/aimodelshare/blob/master/aimodelshare-0.0.2.tar.gz?raw=true
# Out:
# Collecting https://github.com/mikedparrott/aimodelshare/blob/master/aimodelshare-0.0.2.tar.gz?raw=true
#   Downloading https://github.com/mikedparrott/aimodelshare/blob/master/aimodelshare-0.0.2.tar.gz?raw=true
# Building wheels for collected packages: aimodelshare
#   Building wheel for aimodelshare (setup.py): started
#   Building wheel for aimodelshare (setup.py): finished with status 'done'
#   Created wheel for aimodelshare: filename=aimodelshare-0.0.2-cp37-none-any.whl size=5380 sha256=d15e7ba26346a71d84e71f3ebe2d9f80991c99b3e6a07fbfe42c074c0610502e
#   Stored in directory: C:\Users\zacha\AppData\Local\pip\Cache\wheels\31\8d\ac\09cb6ef7374ec79e02843c347195e5478144006b11def6799a
# Successfully built aimodelshare
# Installing collected packages: aimodelshare
# Successfully installed aimodelshare-0.0.2

# %%
import pickle

# Loading AWS keys necessary to submit model.  Loading to object, so we don't print them out in our notebook

aws_key_password_region = pickle.load( open( "worldhappiness_modelsubmission_keys.pkl", "rb" ) )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-9806affe6d78> in <module>
#       3 # Loading AWS keys necessary to submit model.  Loading to object, so we don't print them out in our notebook
#       4
# ----> 5 aws_key_password_region = pickle.load( open( "worldhappiness_modelsubmission_keys.pkl", "rb" ) )
#
# FileNotFoundError: [Errno 2] No such file or directory: 'worldhappiness_modelsubmission_keys.pkl'

# %%
#Importing from object that stores keys so we do not print out keys for others to see.

aws_key_password_region = pickle.load( open( "C:/Users/zacha/Desktop/Coursework Spring 2020/class material/machine learning/worldhappiness_modelsubmission_keys.pkl", "rb" ) )

aws_key=aws_key_password_region[0]
aws_password=aws_key_password_region[1]
region=aws_key_password_region[2]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Submit new model
import aimodelshare as ai

#ai.submit_model(model_filepath=model_filepath, model_eval_metrics=modelevalobject,apiurl=apiurl, username=username, password=password, aws_key=aws_key,aws_password=aws_password, region=region, trainingdata=trainingdata,preprocessor_filepath=preprocessor_filepath,preprocessor=preprocessor)

# %%
apiurl="https://btuvanmi55.execute-api.us-east-1.amazonaws.com/prod/m"
username = username
password = password

# %%
# Check leaderboard
import aimodelshare as ai

leaderboard = ai.get_leaderboard(apiurl, username, password, aws_key, aws_password, region)
# Out:
# LEADERBOARD RANKINGS:
#      accuracy  f1_score  precision    recall  mse  rmse  mae  r2    username  \
# 0    0.717949  0.717857   0.717857  0.727778    0     0    0   0      3scman
# 1    0.717949  0.713796   0.719444  0.725000    0     0    0   0      3scman
# 2    0.666667  0.675975   0.754286  0.700952    0     0    0   0   dhoward97
# 3    0.692308  0.693333   0.700397  0.702778    0     0    0   0      3scman
# 4    0.641026  0.642381   0.743590  0.682273    0     0    0   0  SUN-Wenjun
# ..        ...       ...        ...       ...  ...   ...  ...  ..         ...
# 106  0.333333  0.337698   0.385556  0.322222    0     0    0   0   username2
# 105  0.333333  0.337698   0.385556  0.322222    0     0    0   0   username2
# 104  0.333333  0.337698   0.385556  0.322222    0     0    0   0   username2
# 108  0.333333  0.336015   0.354048  0.325000    0     0    0   0   raquel904
# 107  0.333333  0.336015   0.354048  0.325000    0     0    0   0   raquel904
#
#      model_version  avg_ranking_classification  avg_ranking_regression
# 0               85                    2.333333                     1.0
# 1               70                    2.333333                     1.0
# 2               69                    2.666667                     1.0
# 3               62                    4.000000                     1.0
# 4               83                    4.000000                     1.0
# ..             ...                         ...                     ...
# 106              2                   47.333333                     1.0
# 105              3                   47.333333                     1.0
# 104              6                   47.333333                     1.0
# 108            101                   48.000000                     1.0
# 107            102                   48.000000                     1.0
#
# [122 rows x 12 columns]

# %% [markdown]
# Github: https://github.com/zivzach/Machine-Learning
